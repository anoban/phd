# %% [markdown]
# # ___Phylogenetic analysis of the FRED 4.0 subset___
# ----------------------

# %%
print(R.version$version.string)
# Out:
# [1] "R version 4.6.1 (2026-06-24 ucrt)"

# %%
suppressPackageStartupMessages({
    library("ape")
    library("phytools")
    library("U.PhyloMaker")
    library("phylolm")
    library("geiger")
    library("Rphylopars")
    library("readxl")
    library("RRPP")
    library("geomorph")
    library("car")
    library("nortest")
    library("FSA")
    library("effects")
    library("ggplot2")
    library("broom")
    library("lme4")
})

# %%
packageVersion("phytools")
# Out:
# [1] '2.5.2'

# %%
packageVersion("U.PhyloMaker")
# Out:
# [1] '0.1.0'

# %%
packageVersion("phylolm")
# Out:
# [1] '2.7.0'

# %%
packageVersion("Rphylopars")
# Out:
# [1] '0.3.10'

# %%
packageVersion("geiger")
# Out:
# [1] '2.0.12'

# %% [markdown]
# ## ___1. Phylogeny construction___
# ---------------------------

# %%
megatree <- ape::read.tree("../../data/chapter2/uphylomaker/GBOTB.extended.TPL.tre") # TPL megatree
# the order info in the FRED 4.0 subset dataset wasn't cross checked!!!!
traits <- read.csv("../../data/chapter2/FRED/subsets/final") # FRED 4.0 subset with names reconciled with the megatree by hand
# this does not need programmatic name reconciliations
traits$binominal <- gsub(traits$binominal, pattern = ' ', replacement = '_')
synonyms <- read.csv("../../data/chapter2/wcvp/synonyms.csv") # WCVP synonyms

# %%
#---------------------------
# phylogeney construction
#---------------------------

# species, genus, family, species.relative, genus.relative
species_list <- data.frame(species = traits$binominal, genus = traits$F01286, family = NA, species.relative = NA, genus.relative = NA)
genus_list <- data.frame(genus = traits$F01286, family = traits$F01289) 
phy <- U.PhyloMaker::phylo.maker(sp.list = species_list, gen.list = genus_list, tree = megatree)

# %%
ape::write.tree(phy = phy$phylo, file = "../../data/chapter2/uphylomaker/FRED4_1301_species.tre")

# %%
stopifnot(all(traits[match(phy$phylo$tip.label, traits$binominal), ]$binominal == phy$phylo$tip.label))
traits <- traits[match(phy$phylo$tip.label, traits$binominal), ]
write.csv(traits, "../../data/chapter2/FRED/subsets/final_name_matched.csv", row.names = FALSE)

# %% [raw]
# failed_to_bind <- c("Blechnopsis orientalis", "Lomaria discolor", "Parablechnum novae-zelandiae", "Parablechnum procerum", "Pseudodiphasium volubile", "Richetia multiflora",
#     "Rubroshorea acuminata", "Rubroshorea leprosula")

# %% [raw]
# synonyms[synonyms$synonym %in% failed_to_bind, ]

# %% [raw]
# # gsub(failed_to_bind, pattern = " \\w*-{0,1}", replacement = '')
#
# traits[traits$F01286 %in% c("Parablechnum", "Lomaria", "Blechnopsis"), "F01286"] = "Blechnum"
# traits[traits$F01286 == "Pseudodiphasium", "F01286"] = "Lycopodium"

# %% [raw]
# synonyms[synonyms$name %in% failed_to_bind, ]

# %% [raw]
# traits[traits$F01286 %in% c("Richetia", "Rubroshorea"), "F01286"] = "Shorea"

# %% [raw]
# #---------------------------------
# # re run the phylogeny creation
# #---------------------------------
#
# species_list <- data.frame(species = paste0(traits$F01286, ' ', traits$F01287), genus = traits$F01286, family = NA, species.relative = NA, genus.relative = NA)
# genus_list <- data.frame(genus = traits$F01286, family = traits$F01289)
# phy <- U.PhyloMaker::phylo.maker(sp.list = species_list, gen.list = genus_list, tree = megatree)
#
# ape::write.tree(phy = phy$phylo, file = "../../data/chapter2/uphylomaker/FRED4_1301_species.tre")

# %%
# phylogeny for subset comparison - based on the crtieria used to define fine roots

megatree <- ape::read.tree("../../data/chapter2/uphylomaker/GBOTB.extended.TPL.tre") # TPL megatree
data <- read.csv("../../data/chapter2/FRED/subsets/fineroot-comparison.csv")

species_list <- data.frame(species = data$binominal, genus = data$F01286, family = NA, species.relative = NA, genus.relative = NA)
genus_list <- data.frame(genus = data$F01286, family = data$F01289)

phy <- U.PhyloMaker::phylo.maker(sp.list = species_list, gen.list = genus_list, tree = megatree)

# %%
ape::write.tree(phy$phylo, file = "../../data/chapter2/uphylomaker/fineroot-comparison.tre")

# %%
data$binominal <- data$binominal |> gsub(pattern = ' ', replacement = '_') # replace the spaces with underscores

# %%
# name match the dataset to phylogeny

data <- data[match(phy$phylo$tip.label, data$binominal), ]

# %%
write.csv(data, "../../data/chapter2/FRED/subsets/fineroot-comparison-name-matched.csv", row.names = FALSE)

# %% [markdown]
# ## ___2. Phylogenetic signal and pairwise relationships___
# ---------------------------

# %%
GEIGER_FITCONTINUOUS_MODEL_OPTIONS <- c("BM", "OU", "EB", "rate_trend", "lambda", "kappa", "delta", "mean_trend", "white")
PHYLOLM_PHYLOLM_MODEL_OPTIONS <- c("BM", "OUrandomRoot", "OUfixedRoot", "lambda", "kappa", "delta", "EB", # "trend", - "trend" option is problematic for ultrametric trees
                                   "GC")

# %%
# this phylogeny needs to be fully bifurcating with no polytomies
tree <- ape::read.tree("../../data/chapter2/uphylomaker/FRED4_1301.tre") # the phylogeny of the 1301 FRED 4.0 subset species

if(!ape::is.binary(tree)) tree <- ape::multi2di(tree, random = FALSE) # split polytomies into binary 0 length branches

# make the phylogeny completely bifurcating by replacing 0 length branches
tree$edge.length[tree$edge.length <= 0] <- rnorm(n = sum(tree$edge.length == 0), mean = 1e-6, sd = 1e-8) # replace the 0 length edges with random noise
stopifnot(!sum(tree$edge.length <= 0)) # no more 0 length branches

# this must be done after altering the branch lengths
if (!ape::is.ultrametric(tree)) tree <- phytools::force.ultrametric(tree = tree, method = "extend") # this needs to be done after replacing the 0 length branches with small non zero noise

stopifnot(ape::is.binary(tree) && ape::is.ultrametric(tree))

traits <- read.csv("../../data/chapter2/FRED/subsets/name_matched_FRED4_1301.csv", row.names = "binominal") # we need the binominal names as row names for phylolm::phylolm()

# repeat the taxonomic corrections
# traits[traits$F01286 %in% c("Parablechnum", "Lomaria", "Blechnopsis"), "F01286"] = "Blechnum"
# traits[traits$F01286 == "Pseudodiphasium", "F01286"] = "Lycopodium"
# traits[traits$F01286 %in% c("Richetia", "Rubroshorea"), "F01286"] = "Shorea"

# traits["binominal"] <- paste0(traits$F01286, '_', traits$F01287)
# stopifnot(length(traits$binominal)==length(tree$tip.label))
# stopifnot(sum(tree$tip.label %in% traits$binominal) == length(tree$tip.label))
# traits <- traits[match(tree$tip.label, traits$binominal), ] # name matching the dataset and the phylogeny

stopifnot(all(tree$tip.label==traits$binominal)) # the current traits dataset has already been name matched with the phylogeny!!!!!!!!
# Out:
# ***************************************************************
# *                          Note:                              *
# *    force.ultrametric does not include a formal method to    *
# *    ultrametricize a tree & should only be used to coerce    *
# *   a phylogeny that fails is.ultrametric due to rounding --  *
# *    not as a substitute for formal rate-smoothing methods.   *
# ***************************************************************

# %%
head(traits)
# Out:
#                         F01286    F01289     F00679     F00679_se F00727
# Ratibida_pinnata        Ratibida  Asteraceae -0.8209806 NA        4.025352
# Heliopsis_helianthoides Heliopsis Asteraceae -0.9675840 NA        4.158883
# Liatris_aspera          Liatris   Asteraceae -0.7985077 NA        4.382027
# Arnica_sororia          Arnica    Asteraceae -1.4134600 NA        4.342257
# Arnica_fulgens          Arnica    Asteraceae -0.6627150 NA        2.765172
# Hymenoxys_richardsonii  Hymenoxys Asteraceae -1.2644308 NA        4.235371
#                         F00727_se F00709    F00709_se state
# Ratibida_pinnata        NA        -2.120264 NA        AM
# Heliopsis_helianthoides NA        -1.966113 NA        AM
# Liatris_aspera          NA        -2.525729 NA        AM
# Arnica_sororia          NA        -1.203973 NA        AM
# Arnica_fulgens          NA        -1.124452 NA        AM
# Hymenoxys_richardsonii  NA        -1.460061 NA        AM
#                         state_source
# Ratibida_pinnata        (Soudzilovskaia et al., 2020)
# Heliopsis_helianthoides (Brundrett and Tedersoo, 2018)
# Liatris_aspera          (Maherali et. al. 2016)
# Arnica_sororia          (Soudzilovskaia et al., 2020)
# Arnica_fulgens          (Maherali et. al. 2016)
# Hymenoxys_richardsonii  (Soudzilovskaia et al., 2020)
#                         synonym
# Ratibida_pinnata        ('Lepachys pinnata', 'Rudbeckia pinnata', 'Helianthus pinnatus', 'Obeliscaria pinnata')
# Heliopsis_helianthoides ('Buphthalmum helianthoides',)
# Liatris_aspera          ('Lacinaria scariosa var. aspera', 'Lacinaria aspera')
# Arnica_sororia          ('Arnica fulgens var. sororia',)
# Arnica_fulgens          ('Arnica montana var. fulgens',)
# Hymenoxys_richardsonii  ('Picradenia richardsonii', 'Actinea richardsonii', 'Actinella richardsonii')

# %%
# the tutorial uses the R library phylolm
# nlme::gls requires a correlation matrix - ape provides only limited options (Brownian, Bloomberg, Pagel et.c.) for this

suppressWarnings(
    rbind(
        SRL.RD = mapply(PHYLOLM_PHYLOLM_MODEL_OPTIONS, FUN = function (m) phylolm::phylolm(F00727 ~ F00679, data = traits, model = m, phy = tree)$aic), # SRL ~ RD
        RD.SRL = mapply(PHYLOLM_PHYLOLM_MODEL_OPTIONS, FUN = function (m) phylolm::phylolm(F00679 ~ F00727, data = traits, model = m, phy = tree)$aic) # RD ~ SRL
    )
)
# Out:
#        BM       OUrandomRoot OUfixedRoot lambda     kappa    delta    EB
# SRL.RD 4131.183 2792.9652    2792.9652   2278.52841 2449.473 4028.958 4133.183
# RD.SRL 1773.001  518.9369     518.9369     91.18185  301.745 1673.066 1775.001
#        GC
# SRL.RD 2935.8499
# RD.SRL  794.3364

# %%
suppressWarnings(
    rbind(
        SRL.RTD = mapply(PHYLOLM_PHYLOLM_MODEL_OPTIONS, FUN = function (m) phylolm::phylolm(F00727 ~ F00709, data = traits, model = m, phy = tree)$aic), # SRL ~ RTD
        RTD.SRL = mapply(PHYLOLM_PHYLOLM_MODEL_OPTIONS, FUN = function (m) phylolm::phylolm(F00709 ~ F00727, data = traits, model = m, phy = tree)$aic) # RTD ~ SRL
    )
)
# Out:
#         BM       OUrandomRoot OUfixedRoot lambda   kappa    delta    EB
# SRL.RTD 4546.429 3478.641     3478.641    3011.043 3172.633 4448.019 4548.429
# RTD.SRL 3212.342 2024.360     2024.360    1551.719 1742.431 3112.443 3214.342
#         GC
# SRL.RTD 3648.292
# RTD.SRL 2186.818

# %%
suppressWarnings(
    rbind(
        RTD.RD = mapply(PHYLOLM_PHYLOLM_MODEL_OPTIONS, FUN = function (m) phylolm::phylolm(F00709 ~ F00679, data = traits, model = m, phy = tree)$aic), # RTD ~ RD
        RD.RTD = mapply(PHYLOLM_PHYLOLM_MODEL_OPTIONS, FUN = function (m) phylolm::phylolm(F00679 ~ F00709, data = traits, model = m, phy = tree)$aic) # RD ~ RTD
    )
)
# Out:
#        BM       OUrandomRoot OUfixedRoot lambda   kappa    delta    EB
# RTD.RD 3754.571 2467.833     2467.833    1940.750 2097.047 3652.552 3756.571
# RD.RTD 2857.176 1725.364     1725.364    1239.566 1413.929 2757.907 2859.176
#        GC
# RTD.RD 2547.834
# RD.RTD 1917.285

# %%
table(traits$state)
# Out:
#    AM   EcM EcMAM   ErM    NM  NMAM
#  1097   121    20     9    16    38

# %% [markdown]
# ## ___Pairwise correlations with all the records___
# ------------------------------

# %%
STATE_COLOURS <- c(AM = "#E7BC0C", EcM = "#23B9AF", ErM = "#6B6CF2", NM = "#11E823", NMAM = "#2D2E30", EcMAM = "#E71A23")

# %%
traits$colour <- unname(STATE_COLOURS[traits$state])

# %%
# options(repr.plot.width = 6, repr.plot.height = 6)

# %%
# INSTEAD OF FITTING A SIMPLE LINEAR REGRESSION MODEL FOR ALL DATA POINTS - SEEMS LIKE A BETTER IDEA TO FIT A MIXED EFFECT MODEL FOR

# %%
plot(d$F00679, predict(m))
# Out:
# plot without title

# %%
p <- ggplot() + theme_bw()

for (n in names(STATE_COLOURS)) 
    d <- subset(traits, state == n)
    m <- phylolm::phylolm(F00727 ~ F00679, data = d, model = "lambda", phy = tree, upper.bound = 1, lower.bound = 1e-10)
    p <- p + geom_point(x = d$F00679, y = predict(m)) +
            geom_line(x = d$F00679, y = predict(m))
# Out:
# Warning message in phylolm::phylolm(F00727 ~ F00679, data = d, model = "lambda", :
# "will drop from the tree 1281 taxa with missing data"

# %%
plot(p)
# Out:
# plot without title

# %%
lme4::lmer(F00727 ~ (F00679|state), data = traits)
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: F00727 ~ (F00679 | state)
#    Data: traits
# REML criterion at convergence: 2868.774
# Random effects:
#  Groups   Name        Std.Dev. Corr
#  state    (Intercept) 2.4951
#           F00679      1.6409   0.99
#  Residual             0.7172
# Number of obs: 1301, groups:  state, 6
# Fixed Effects:
# (Intercept)
#       4.479

# %%
source("./../phylolm_patched.R")

# %%
traits |> split(~state) |> lapply(FUN = nrow)
# Out:
# $AM
# [1] 1097
#
# $EcM
# [1] 121
#
# $EcMAM
# [1] 20
#
# $ErM
# [1] 9
#
# $NM
# [1] 16
#
# $NMAM
# [1] 38

# %%
group_names <- traits |> split(~state) |> lapply(FUN = rownames) |> as.vector()

# %%
names(group_names) <- group_names |> lapply(FUN = length) |> unname() # replace
# Out:
# [1] "AM"    "EcM"   "EcMAM" "ErM"   "NM"    "NMAM"

# %%
p <- ggplot(aes(x = F00679, y = F00727, group = state, bg = I(colour)), data = traits) + 
    geom_point(pch = 21, color = "black") +
    stat_smooth(method = "lm") +
    geom_smooth(inherit.aes = TRUE, method = phylolm_patched, method.args = list(phy = tree, model = "lambda", nms = group_names)) + 
    xlab("RD") +
    ylab("SRL") +
    theme_bw()

# %%
p
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message in method(formula, data = data, weights = weight, phy = structure(list(:
# "will drop from the tree 1301 taxa with missing data"
# Warning message in drop.tip.phylo(phy, taxa_without_data):
# "drop all tips of the tree: returning NULL"
# Warning message:
# "Failed to fit group 1.
# Caused by error in `method()`:
# ! names of the data do not match with tip labels."
# Warning message in method(formula, data = data, weights = weight, phy = structure(list(:
# "will drop from the tree 1301 taxa with missing data"
# Warning message in drop.tip.phylo(phy, taxa_without_data):
# "drop all tips of the tree: returning NULL"
# Warning message:
# "Failed to fit group 2.
# Caused by error in `method()`:
# ! names of the data do not match with tip labels."
# Warning message in method(formula, data = data, weights = weight, phy = structure(list(:
# "will drop from the tree 1301 taxa with missing data"
# Warning message in drop.tip.phylo(phy, taxa_without_data):
# "drop all tips of the tree: returning NULL"
# Warning message:
# "Failed to fit group 3.
# Caused by error in `method()`:
# ! names of the data do not match with tip labels."
# Warning message in method(formula, data = data, weights = weight, phy = structure(list(:
# "will drop from the tree 1301 taxa with missing data"
# Warning message in drop.tip.phylo(phy, taxa_without_data):
# "drop all tips of the tree: returning NULL"
# Warning message:
# "Failed to fit group 4.
# Caused by error in `method()`:
# ! names of the data do not match with tip labels."
# Warning message in method(formula, data = data, weights = weight, phy = structure(list(:
# "will drop from the tree 1301 taxa with missing data"
# Warning message in drop.tip.phylo(phy, taxa_without_data):
# "drop all tips of the tree: returning NULL"
# Warning message:
# "Failed to fit group 5.
# Caused by error in `method()`:
# ! names of the data do not match with tip labels."
# Warning message in method(formula, data = data, weights = weight, phy = structure(list(:
# "will drop from the tree 1301 taxa with missing data"
# Warning message in drop.tip.phylo(phy, taxa_without_data):
# "drop all tips of the tree: returning NULL"
# Warning message:
# "Failed to fit group 6.
# Caused by error in `method()`:
# ! names of the data do not match with tip labels."
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# $AM
#    [1] "Ratibida_pinnata"                 "Heliopsis_helianthoides"
#    [3] "Liatris_aspera"                   "Arnica_sororia"
#    [5] "Arnica_fulgens"                   "Hymenoxys_richardsonii"
#    [7] "Helianthus_agrestis"              "Helianthus_grosseserratus"
#    [9] "Helianthus_giganteus"             "Helianthus_maximiliani"
#   [11] "Helianthus_verticillatus"         "Helianthus_salicifolius"
#   [13] "Pappobolus_microphyllus"          "Helianthus_occidentalis"
#   [15] "Helianthus_mollis"                "Helianthus_silphioides"
#   [17] "Helianthus_atrorubens"            "Helianthus_longifolius"
#   [19] "Helianthus_angustifolius"         "Helianthus_floridanus"
#   [21] "Helianthus_petiolaris"            "Helianthus_neglectus"
#   [23] "Helianthus_niveus"                "Helianthus_praecox"
#   [25] "Helianthus_debilis"               "Helianthus_argophyllus"
#   [27] "Helianthus_annuus"                "Helianthus_cusickii"
#   [29] "Helianthus_pauciflorus"           "Helianthus_radula"
#   [31] "Helianthus_porteri"               "Helianthus_carnosus"
#   [33] "Helianthus_heterophyllus"         "Ambrosia_artemisiifolia"
#   [35] "Echinacea_serotina"               "Coreopsis_palmata"
#   [37] "Helichrysum_italicum"             "Helichrysum_stoechas"
#   [39] "Anaphalis_aureopunctata"          "Anaphalis_hancockii"
#   [41] "Antennaria_parvifolia"            "Antennaria_neglecta"
#   [43] "Inula_conyza"                     "Xanthisma_spinulosum"
#   [45] "Symphyotrichum_oolentangiense"    "Symphyotrichum_falcatum"
#   [47] "Symphyotrichum_ciliolatum"        "Symphyotrichum_puniceum"
#   [49] "Symphyotrichum_laeve"             "Symphyotrichum_novae-angliae"
#   [51] "Symphyotrichum_ericoides"         "Chrysopsis_villosa"
#   [53] "Solidago_ptarmicoides"            "Solidago_nemoralis"
#   [55] "Solidago_decurrens"               "Solidago_speciosa"
#   [57] "Solidago_rigida"                  "Solidago_missouriensis"
#   [59] "Gutierrezia_sarothrae"            "Erigeron_glabellus"
#   [61] "Erigeron_pumilus"                 "Erigeron_canadensis"
#   [63] "Aster_scaber"                     "Aster_lanceolatus"
#   [65] "Aster_tataricus"                  "Olearia_avicenniaefolia"
#   [67] "Olearia_rani"                     "Artemisia_igniaria"
#   [69] "Artemisia_barrelieri"             "Artemisia_frigida"
#   [71] "Artemisia_mongolica"              "Artemisia_ludoviciana"
#   [73] "Artemisia_cana"                   "Achillea_millefolium"
#   [75] "Crepis_foetida"                   "Crepis_tectorum"
#   [77] "Taraxacum_campylodes"             "Picris_hieracioides"
#   [79] "Nabalus_tatarinowii"              "Launaea_arborescens"
#   [81] "Lactuca_tatarica"                 "Pilosella_officinarum"
#   [83] "Lygodesmia_juncea"                "Cichorium_intybus"
#   [85] "Tragopogon_dubius"                "Critoniopsis_pycnantha"
#   [87] "Critoniopsis_floribunda"          "Vernonia_fasciculata"
#   [89] "Centaurea_pectinata"              "Saussurea_nivea"
#   [91] "Saussurea_mongolica"              "Saussurea_amurensis"
#   [93] "Atractylis_humilis"               "Adenocaulon_himalaicum"
#   [95] "Campanula_rotundifolia"           "Carpodetus_serratus"
#   [97] "Musineon_divaricatum"             "Zizia_aurea"
#   [99] "Tordylium_maximum"                "Daucus_carota"
#  [101] "Sanicula_orthacantha"             "Sciodaphyllum_acuminatum"
#  [103] "Heptapleurum_heptaphyllum"        "Heptapleurum_minutistellatum"
#  [105] "Schefflera_digita"                "Oreopanax_sessiliflorus"
#  [107] "Dendropanax_dentigerus"           "Eleutherococcus_senticosus"
#  [109] "Macropanax_undulatus"             "Hedera_helix"
#  [111] "Neopanax_arboreus"                "Neopanax_colensoi"
#  [113] "Pseudopanax_crassifolius"         "Raukaua_simplex"
#  [115] "Pittosporum_eugenioides"          "Pittosporum_tenuifolium"
#  [117] "Pennantia_corymbosa"              "Zabelia_biflora"
#  [119] "Lonicera_chrysantha"              "Lonicera_maackii"
#  [121] "Symphoricarpos_occidentalis"      "Viburnum_stipitatum"
#  [123] "Viburnum_dentatum"                "Viburnum_tinus"
#  [125] "Sambucus_williamsii"              "Quintinia_serrata"
#  [127] "Ilex_macropoda"                   "Ilex_verticillata"
#  [129] "Ilex_teratopis"                   "Ilex_laurina"
#  [131] "Ilex_opaca"                       "Ilex_pedunculosa"
#  [133] "Pseudodictamnus_hirsutus"         "Hedeoma_hispida"
#  [135] "Monarda_fistulosa"                "Pycnanthemum_virginianum"
#  [137] "Clinopodium_nepeta"               "Thymus_mastichina"
#  [139] "Thymus_hyemalis"                  "Thymus_dolomiticus"
#  [141] "Agastache_foeniculum"             "Salvia_rosmarinus"
#  [143] "Salvia_chinensis"                 "Lavandula_multifida"
#  [145] "Teucrium_charidemi"               "Teucrium_chamaedrys"
#  [147] "Teucrium_fruticans"               "Phlomoides_umbrosa"
#  [149] "Phlomis_purpurea"                 "Sideritis_pusilla"
#  [151] "Vitex_lucens"                     "Strobilanthes_dimorphotricha"
#  [153] "Handroanthus_guayacan"            "Handroanthus_ochraceus"
#  [155] "Tanaecium_pyramidatum"            "Catalpa_bignonioides"
#  [157] "Verbena_hastata"                  "Verbascum_thapsus"
#  [159] "Veronica_persica"                 "Veronica_spuria"
#  [161] "Veronicastrum_virginicum"         "Plantago_lanceolata"
#  [163] "Plantago_patagonica"              "Penstemon_bradburyi"
#  [165] "Penstemon_nitidus"                "Penstemon_procerus"
#  [167] "Penstemon_confertus"              "Tetrapilus_roseus"
#  [169] "Chrysojasminum_fruticans"         "Noronhia_mildbraedii"
#  [171] "Olea_europaea"                    "Chionanthus_virginicus"
#  [173] "Phillyrea_angustifolia"           "Phillyrea_latifolia"
#  [175] "Osmanthus_didymopetalus"          "Nestegis_lanceolata"
#  [177] "Fraxinus_mandshurica"             "Fraxinus_angustifolia"
#  [179] "Fraxinus_excelsior"               "Fraxinus_chinensis"
#  [181] "Fraxinus_nigra"                   "Fraxinus_americana"
#  [183] "Syringa_reticulata"               "Stachyarrhena_acuminata"
#  [185] "Eumachia_astrellantha"            "Eumachia_podocephala"
#  [187] "Rubia_peregrina"                  "Saprosma_ternatum"
#  [189] "Coprosma_lucida"                  "Coprosma_linariifolia"
#  [191] "Coprosma_rhamnoides"              "Coprosma_ciliata"
#  [193] "Coprosma_foetidissima"            "Psychotria_rhombibractea"
#  [195] "Psychotria_asiatica"              "Chassalia_subnuda"
#  [197] "Rudgea_lanceifolia"               "Rudgea_cornifolia"
#  [199] "Palicourea_virens"                "Palicourea_tinctoria"
#  [201] "Palicourea_thyrsiflora"           "Palicourea_stenosepala"
#  [203] "Palicourea_spicata"               "Palicourea_hoffmannseggiana"
#  [205] "Palicourea_dichotoma"             "Palicourea_corymbifera"
#  [207] "Palicourea_amplectens"            "Carapichea_pacimonica"
#  [209] "Pagamea_macrophylla"              "Faramea_platyneura"
#  [211] "Faramea_capillipes"               "Faramea_bangii"
#  [213] "Faramea_torquata"                 "Catunaregam_spinosa"
#  [215] "Aidia_oxyodonta"                  "Amaioua_glomerulata"
#  [217] "Amaioua_guianensis"               "Kutchubaea_sericantha"
#  [219] "Kutchubaea_semisericea"           "Kutchubaea_oocarpa"
#  [221] "Alibertia_edulis"                 "Alibertia_claviflora"
#  [223] "Cordiera_myrciifolia"             "Agouticarpa_curviflora"
#  [225] "Diplospora_dubia"                 "Hypobathrum_racemosum"
#  [227] "Wendlandia_uvariifolia"           "Ixora_panurensis"
#  [229] "Ixora_intensa"                    "Alseis_blackiana"
#  [231] "Adina_metcalfii"                  "Adina_pilulifera"
#  [233] "Ladenbergia_riveroana"            "Chomelia_psilocarpa"
#  [235] "Chomelia_tenuiflora"              "Bathysa_australis"
#  [237] "Ferdinandusa_rudgeoides"          "Ferdinandusa_hirsuta"
#  [239] "Simira_rubescens"                 "Asclepias_tuberosa"
#  [241] "Asclepias_syriaca"                "Asclepias_incarnata"
#  [243] "Nerium_oleander"                  "Trachelospermum_axillare"
#  [245] "Alstonia_scholaris"               "Gentiana_andrewsii"
#  [247] "Physalis_virginiana"              "Withania_frutescens"
#  [249] "Cestrum_schlechtendalii"          "Apodytes_dimidiata"
#  [251] "Clethra_revoluta"                 "Actinidia_kolomikta"
#  [253] "Saurauia_herthae"                 "Symplocos_cochinchinensis"
#  [255] "Styrax_suberifolius"              "Halesia_tetraptera"
#  [257] "Alniphyllum_fortunei"             "Geissanthus_vanderwerffii"
#  [259] "Androsace_occidentalis"           "Ardisia_depressa"
#  [261] "Ardisia_quinquegona"              "Ardisia_japonica"
#  [263] "Embelia_vestita"                  "Myrsine_divaricata"
#  [265] "Myrsine_coriacea"                 "Myrsine_australis"
#  [267] "Myrsine_andina"                   "Myrsine_seguinii"
#  [269] "Diospyros_strigosa"               "Diospyros_virginiana"
#  [271] "Eschweilera_tenuifolia"           "Eschweilera_bracteosa"
#  [273] "Eschweilera_decolorans"           "Eschweilera_pedicellata"
#  [275] "Eschweilera_wachenheimii"         "Eschweilera_ovata"
#  [277] "Eschweilera_coriacea"             "Eschweilera_parviflora"
#  [279] "Eschweilera_truncata"             "Eschweilera_albiflora"
#  [281] "Eschweilera_atropetiolata"        "Eschweilera_grandiflora"
#  [283] "Allantoma_lineata"                "Grias_peruviana"
#  [285] "Barringtonia_fusicarpa"           "Barringtonia_racemosa"
#  [287] "Pouteria_austin-smithii"          "Pouteria_cuspidata"
#  [289] "Pouteria_caimito"                 "Chromolucuma_rubriflora"
#  [291] "Chrysophyllum_sanguinolentum"     "Micropholis_trunciflora"
#  [293] "Micropholis_mensalis"             "Micropholis_cylindrocarpa"
#  [295] "Micropholis_venulosa"             "Micropholis_egensis"
#  [297] "Micropholis_casiquiarensis"       "Micropholis_guyanensis"
#  [299] "Planchonella_grandifolia"         "Madhuca_endertii"
#  [301] "Payena_microphylla"               "Polyspora_axillaris"
#  [303] "Gordonia_fruticosa"               "Schima_superba"
#  [305] "Schima_wallichii"                 "Phlox_hoodii"
#  [307] "Eurya_japonica"                   "Ternstroemia_coriacea"
#  [309] "Pentaphylax_euryoides"            "Deutzia_glabrata"
#  [311] "Deutzia_grandiflora"              "Philadelphus_incanus"
#  [313] "Cornus_bretschneideri"            "Cornus_ulotricha"
#  [315] "Cornus_controversa"               "Cornus_kousa"
#  [317] "Cornus_florida"                   "Cornus_officinalis"
#  [319] "Alangium_chinense"                "Nyssa_aquatica"
#  [321] "Nyssa_sylvatica"                  "Krascheninnikovia_ceratoides"
#  [323] "Schoepfia_jasminodora"            "Comandra_umbellata"
#  [325] "Stauracanthus_genistoides"        "Imbralyx_leptobotrys"
#  [327] "Trifolium_repens"                 "Trifolium_pratense"
#  [329] "Trifolium_angustifolium"          "Trifolium_purpureum"
#  [331] "Trifolium_subterraneum"           "Medicago_sativa"
#  [333] "Medicago_ruthenica"               "Medicago_minima"
#  [335] "Melilotus_officinalis"            "Vicia_americana"
#  [337] "Vicia_villosa"                    "Lathyrus_venosus"
#  [339] "Astragalus_bisulcatus"            "Astragalus_agrestis"
#  [341] "Astragalus_scaberrimus"           "Astragalus_canadensis"
#  [343] "Astragalus_aboriginum"            "Oxytropis_sericea"
#  [345] "Lotus_corniculatus"               "Anthyllis_cytisoides"
#  [347] "Anthyllis_terniflora"             "Coronilla_juncea"
#  [349] "Coronilla_minima"                 "Bituminaria_bituminosa"
#  [351] "Desmodium_canadense"              "Lespedeza_bicolor"
#  [353] "Lespedeza_davurica"               "Lespedeza_thunbergii"
#  [355] "Lespedeza_capitata"               "Millettia_leptobotrya"
#  [357] "Clitoria_javitensis"              "Dalea_purpurea"
#  [359] "Cytisus_grandiflorus"             "Genista_triacanthos"
#  [361] "Genista_hirsuta"                  "Ulex_parviflorus"
#  [363] "Calpurnia_aurea"                  "Thermopsis_rhombifolia"
#  [365] "Baptisia_alba"                    "Platypodium_elegans"
#  [367] "Sophora_microphylla"              "Dussia_tessmannii"
#  [369] "Styphnolobium_japonicum"          "Inga_suberosa"
#  [371] "Inga_splendens"                   "Inga_rubiginosa"
#  [373] "Inga_obidensis"                   "Inga_marginata"
#  [375] "Inga_macrophylla"                 "Inga_loubryana"
#  [377] "Inga_lateriflora"                 "Inga_gracilifolia"
#  [379] "Inga_extra-nodis"                 "Inga_cordatoalata"
#  [381] "Inga_cayennensis"                 "Inga_bicoloriflora"
#  [383] "Inga_thibaudiana"                 "Inga_umbratica"
#  [385] "Inga_nobilis"                     "Inga_auristellae"
#  [387] "Inga_ruiziana"                    "Inga_stipularis"
#  [389] "Inga_umbellifera"                 "Inga_brevipes"
#  [391] "Inga_alba"                        "Inga_paraensis"
#  [393] "Inga_huberi"                      "Zygia_inaequalis"
#  [395] "Archidendron_lucidum"             "Archidendron_clypearia"
#  [397] "Calliandra_houstoniana"           "Chamaecrista_fasciculata"
#  [399] "Gleditsia_triacanthos"            "Cercis_canadensis"
#  [401] "Xanthophyllum_tenue"              "Xanthophyllum_flavescens"
#  [403] "Potentilla_tenacetifolia"         "Potentilla_pusilla"
#  [405] "Potentilla_indica"                "Potentilla_acaulis"
#  [407] "Sibbaldianthe_bifurca"            "Drymocallis_arguta"
#  [409] "Chamaerhodos_erecta"              "Sanguisorba_officinalis"
#  [411] "Sanguisorba_minor"                "Agrimonia_pilosa"
#  [413] "Rosa_arkansana"                   "Rosa_canina"
#  [415] "Rosa_acicularis"                  "Rosa_xanthina"
#  [417] "Rubus_irritans"                   "Rubus_ulmifolius"
#  [419] "Rubus_allegheniensis"             "Rubus_rosifolius"
#  [421] "Rubus_crataegifolius"             "Rubus_phoenicolasius"
#  [423] "Rubus_idaeus"                     "Filipendula_digitata"
#  [425] "Spiraea_ouensanensis"             "Malus_baccata"
#  [427] "Cydonia_oblonga"                  "Crataegus_pinnatifida"
#  [429] "Crataegus_monogyna"               "Cotoneaster_multiflorus"
#  [431] "Cotoneaster_adpressus"            "Cotoneaster_acutifolius"
#  [433] "Pyrus_bourgaeana"                 "Pyrus_betulifolia"
#  [435] "Sorbus_discolor"                  "Sorbus_aucuparia"
#  [437] "Eriobotrya_japonica"              "Rhaphiolepis_indica"
#  [439] "Amelanchier_alnifolia"            "Spiraea_dahurica"
#  [441] "Prunus_opaca"                     "Prunus_herthae"
#  [443] "Prunus_armeniaca"                 "Prunus_sargentii"
#  [445] "Prunus_avium"                     "Prunus_serotina"
#  [447] "Prunus_padus"                     "Pseudolmedia_rigida"
#  [449] "Pseudolmedia_laevigata"           "Pseudolmedia_laevis"
#  [451] "Clarisia_biflora"                 "Clarisia_racemosa"
#  [453] "Ficus_sodiroi"                    "Ficus_simplicissima"
#  [455] "Ficus_apollinaris"                "Ficus_variolosa"
#  [457] "Ficus_langkokensis"               "Ficus_carica"
#  [459] "Ficus_fistulosa"                  "Ficus_vasculosa"
#  [461] "Ficus_pertusa"                    "Ficus_citrifolia"
#  [463] "Ficus_maclellandii"               "Ficus_tonduzii"
#  [465] "Helicostylis_tovarensis"          "Helicostylis_scabra"
#  [467] "Helicostylis_tomentosa"           "Maquira_sclerophylla"
#  [469] "Maquira_coriacea"                 "Maquira_calophylla"
#  [471] "Naucleopsis_ternstroemiiflora"    "Naucleopsis_krukovii"
#  [473] "Naucleopsis_insculptula"          "Naucleopsis_imitans"
#  [475] "Naucleopsis_francisci"            "Naucleopsis_caloneura"
#  [477] "Antiaris_toxicaria"               "Brosimum_utile"
#  [479] "Brosimum_rubescens"               "Brosimum_lactescens"
#  [481] "Trymatococcus_amazonicus"         "Artocarpus_lakoocha"
#  [483] "Artocarpus_styracifolius"         "Morus_insignis"
#  [485] "Sorocea_pubivena"                 "Sorocea_guilleminiana"
#  [487] "Sorocea_muriculata"               "Pourouma_cecropiifolia"
#  [489] "Cecropia_angustifolia"            "Celtis_timorensis"
#  [491] "Celtis_australis"                 "Celtis_tetrandra"
#  [493] "Celtis_sinensis"                  "Gironniera_subaequalis"
#  [495] "Ulmus_minor"                      "Ulmus_macrocarpa"
#  [497] "Ulmus_pumila"                     "Ulmus_davidiana"
#  [499] "Ulmus_rubra"                      "Ulmus_americana"
#  [501] "Rhamnus_davurica"                 "Rhamnus_lycioides"
#  [503] "Rhamnus_alaternus"                "Elaeagnus_commutata"
#  [505] "Coriaria_arborea"                 "Coriaria_nepalensis"
#  [507] "Corynocarpus_laevigatus"          "Juglans_nigra"
#  [509] "Juglans_mandshurica"              "Cratoxylum_cochinchinense"
#  [511] "Clusia_ducuoides"                 "Clusia_alata"
#  [513] "Clusia_elliptica"                 "Garcinia_cowa"
#  [515] "Garcinia_oblongifolia"            "Garcinia_xanthochymus"
#  [517] "Dovyalis_abyssinica"              "Viola_adunca"
#  [519] "Melicytus_ramiflorus"             "Leonia_glycycarpa"
#  [521] "Glochidion_lanceolarium"          "Glochidion_eriocarpum"
#  [523] "Antidesma_maclurei"               "Hieronyma_macrocarpa"
#  [525] "Hieronyma_fendleri"               "Hieronyma_asperifolia"
#  [527] "Hieronyma_oblonga"                "Aporosa_subcaudata"
#  [529] "Aporosa_octandra"                 "Aporosa_yunnanensis"
#  [531] "Baccaurea_ramiflora"              "Carallia_brachiata"
#  [533] "Galearia_maingayi"                "Leptobalanus_sprucei"
#  [535] "Leptobalanus_octandrus"           "Leptobalanus_longistylus"
#  [537] "Leptobalanus_granvillei"          "Leptobalanus_latus"
#  [539] "Hymenopus_sothersiae"             "Hymenopus_reticulatus"
#  [541] "Hymenopus_macrophyllus"           "Hymenopus_adolphoduckei"
#  [543] "Hymenopus_caudatus"               "Licania_rodriguesii"
#  [545] "Licania_parviflora"               "Licania_niloi"
#  [547] "Licania_harlingii"                "Licania_gracilipes"
#  [549] "Licania_bracteata"                "Licania_irwinii"
#  [551] "Licania_micrantha"                "Licania_ovalifolia"
#  [553] "Licania_hypoleuca"                "Couepia_magnoliifolia"
#  [555] "Sapium_stylare"                   "Croton_kongensis"
#  [557] "Endospermum_chinense"             "Macaranga_sampsonii"
#  [559] "Mallotus_paniculatus"             "Cleidion_brevipetiolatum"
#  [561] "Blumeodendron_tokbrai"            "Alchornea_tiliifolia"
#  [563] "Alchornea_trewioides"             "Linum_lewisii"
#  [565] "Roucheria_columbiana"             "Elaeocarpus_dentatus"
#  [567] "Elaeocarpus_hookerianus"          "Elaeocarpus_dubius"
#  [569] "Elaeocarpus_sylvestris"           "Elaeocarpus_glabripetalus"
#  [571] "Sloanea_rufa"                     "Sloanea_grandiflora"
#  [573] "Aristotelia_serrata"              "Pterophylla_faxinea"
#  [575] "Pterophylla_racemosa"             "Ackama_rosifolia"
#  [577] "Weinmannia_microphylla"           "Weinmannia_magnifolia"
#  [579] "Weinmannia_fagaroides"            "Weinmannia_elliptica"
#  [581] "Weinmannia_silvicola"             "Weinmannia_ovata"
#  [583] "Prionostemma_aspera"              "Gymnosporia_arbutifolia"
#  [585] "Euonymus_alatus"                  "Euonymus_verrucosus"
#  [587] "Maytenus_schippii"                "Microtropis_discolor"
#  [589] "Microcos_paniculata"              "Sphaeralcea_coccinea"
#  [591] "Hoheria_lyallii"                  "Hoheria_sexstylosa"
#  [593] "Plagianthus_regius"               "Eriotheca_surinamensis"
#  [595] "Eriotheca_longitubulosa"          "Pachira_macrocalyx"
#  [597] "Pachira_minor"                    "Pachira_insignis"
#  [599] "Scleronema_micranthum"            "Catostemma_sclerophyllum"
#  [601] "Pterospermum_acerifolium"         "Sterculia_monosperma"
#  [603] "Sterculia_lanceolata"             "Theobroma_cacao"
#  [605] "Heliocarpus_americanus"           "Thymelaea_hirsuta"
#  [607] "Tetractomia_tetrandra"            "Melicope_pteleifolia"
#  [609] "Vepris_nobilis"                   "Phellodendron_amurense"
#  [611] "Acronychia_pedunculata"           "Micromelum_integerrimum"
#  [613] "Prasoxylon_excelsum"              "Didymocheton_spectabilis"
#  [615] "Aglaia_exstipulata"               "Aglaia_odoratissima"
#  [617] "Aphanamixis_polystachya"          "Guarea_subandina"
#  [619] "Guarea_kunthiana"                 "Guarea_macrophylla"
#  [621] "Ruagea_glabra"                    "Trichilia_septentrionalis"
#  [623] "Ekebergia_capensis"               "Cedrela_montana"
#  [625] "Ailanthus_fordii"                 "Picrasma_longistaminea"
#  [627] "Pometia_pinnata"                  "Acer_fabri"
#  [629] "Acer_caudatum"                    "Acer_negundo"
#  [631] "Acer_barbinerve"                  "Acer_campbellii"
#  [633] "Acer_tegmentosum"                 "Acer_davidii"
#  [635] "Acer_pictum"                      "Acer_truncatum"
#  [637] "Acer_campestre"                   "Acer_platanoides"
#  [639] "Acer_saccharum"                   "Acer_triflorum"
#  [641] "Acer_coriaceifolium"              "Acer_tataricum"
#  [643] "Acer_rubrum"                      "Acer_laurinum"
#  [645] "Acer_pseudoplatanus"              "Aesculus_hippocastanum"
#  [647] "Aesculus_parviflora"              "Matayba_peruviana"
#  [649] "Matayba_inelegans"                "Nephelium_lappaceum"
#  [651] "Allophylus_cobbe"                 "Allophylus_abyssinicus"
#  [653] "Alectryon_excelsus"               "Lepisanthes_senegalensis"
#  [655] "Koelreuteria_paniculata"          "Harpullia_cupanioides"
#  [657] "Canarium_subulatum"               "Canarium_album"
#  [659] "Dacryodes_peruviana"              "Trattinnickia_lawrancei"
#  [661] "Garuga_floribunda"                "Protium_tenuifolium"
#  [663] "Protium_spruceanum"               "Protium_pilosissimum"
#  [665] "Protium_paniculatum"              "Protium_occultum"
#  [667] "Protium_laxiflorum"               "Protium_hebetatum"
#  [669] "Protium_grandifolium"             "Protium_gallosum"
#  [671] "Protium_calanense"                "Protium_amazonicum"
#  [673] "Protium_calendulinum"             "Protium_apiculatum"
#  [675] "Protium_urophyllidium"            "Protium_giganteum"
#  [677] "Protium_trifoliolatum"            "Protium_divaricatum"
#  [679] "Protium_unifoliolatum"            "Protium_pilosum"
#  [681] "Protium_decandrum"                "Protium_elegans"
#  [683] "Protium_heptaphyllum"             "Protium_aracouchini"
#  [685] "Protium_opacum"                   "Protium_strumosum"
#  [687] "Protium_altsonii"                 "Protium_crassipetalum"
#  [689] "Protium_subserratum"              "Protium_ferrugineum"
#  [691] "Protium_sagotianum"               "Rhus_typhina"
#  [693] "Pistacia_terebinthus"             "Pistacia_chinensis"
#  [695] "Pistacia_lentiscus"               "Toxicodendron_acuminatum"
#  [697] "Semecarpus_reticulata"            "Tapirira_guianensis"
#  [699] "Choerospondias_axillaris"         "Pentaspadon_motleyi"
#  [701] "Picramnia_latifolia"              "Turpinia_occidentalis"
#  [703] "Pleroma_ochypetalum"              "Andesanthus_lepidotus"
#  [705] "Miconia_radula"                   "Miconia_crebribullata"
#  [707] "Miconia_calophylla"               "Miconia_dolichorrhyncha"
#  [709] "Miconia_punctata"                 "Miconia_jahnii"
#  [711] "Meriania_franciscana"             "Centronia_laurifolia"
#  [713] "Graffenrieda_uribei"              "Graffenrieda_emarginata"
#  [715] "Graffenrieda_harlingii"           "Blastus_cochinchinensis"
#  [717] "Blastus_pauciflorus"              "Memecylon_nigrescens"
#  [719] "Eugenia_spruceana"                "Eugenia_sinemariensis"
#  [721] "Eugenia_pusilliflora"             "Eugenia_protenta"
#  [723] "Eugenia_patrisii"                 "Eugenia_lisboae"
#  [725] "Eugenia_lambertiana"              "Eugenia_florida"
#  [727] "Eugenia_pseudopsidium"            "Eugenia_biflora"
#  [729] "Myrcianthes_rhopaloides"          "Blepharocalyx_eggersii"
#  [731] "Myrcia_umbraticola"               "Myrcia_sylvatica"
#  [733] "Myrcia_subsericea"                "Myrcia_servata"
#  [735] "Myrcia_paivae"                    "Myrcia_neospeciosa"
#  [737] "Myrcia_integra"                   "Myrcia_grandis"
#  [739] "Myrcia_ferruginea"                "Myrcia_fenestrata"
#  [741] "Myrcia_cuspidata"                 "Myrcia_crebra"
#  [743] "Myrcia_caudata"                   "Myrcia_splendens"
#  [745] "Myrcia_bracteata"                 "Myrcia_citrifolia"
#  [747] "Myrciaria_tenella"                "Myrciaria_floribunda"
#  [749] "Neomyrtus_pedunculata"            "Myrtus_communis"
#  [751] "Calycolpus_goetheanus"            "Decaspermum_gracilentum"
#  [753] "Syzygium_subdecussatum"           "Syzygium_pachysepalum"
#  [755] "Syzygium_napiforme"               "Syzygium_kunstleri"
#  [757] "Syzygium_castaneum"               "Syzygium_borbonicum"
#  [759] "Syzygium_hancei"                  "Syzygium_levinei"
#  [761] "Syzygium_jambos"                  "Syzygium_globiflorum"
#  [763] "Syzygium_maire"                   "Syzygium_acuminatissimum"
#  [765] "Metrosideros_umbellata"           "Metrosideros_robusta"
#  [767] "Metrosideros_excelsa"             "Metrosideros_diffusa"
#  [769] "Metrosideros_fulgens"             "Oenothera_biennis"
#  [771] "Fuchsia_excorticata"              "Combretum_decandrum"
#  [773] "Combretum_collinum"               "Terminalia_amazonia"
#  [775] "Geranium_rotundifolium"           "Vitis_amurensis"
#  [777] "Vitis_vulpina"                    "Vitis_vinifera"
#  [779] "Parthenocissus_quinquefolia"      "Itea_chinensis"
#  [781] "Hamamelis_virginiana"             "Mytilaria_laosensis"
#  [783] "Rhodoleia_championii"             "Liquidambar_obovata"
#  [785] "Liquidambar_gracilipes"           "Liquidambar_formosana"
#  [787] "Liquidambar_styraciflua"          "Daphniphyllum_pentandrum"
#  [789] "Cercidiphyllum_japonicum"         "Platanus_acerifolia"
#  [791] "Platanus_occidentalis"            "Anemone_cylindrica"
#  [793] "Actaea_cimicifuga"                "Thalictrum_simplex"
#  [795] "Berberis_thunbergii"              "Caulophyllum_robustum"
#  [797] "Podophyllum_peltatum"             "Euptelea_pleiosperma"
#  [799] "Convallaria_majalis"              "Asparagus_schoberioides"
#  [801] "Hosta_ventricosa"                 "Allium_tenuissimum"
#  [803] "Allium_bidentatum"                "Allium_textile"
#  [805] "Iris_japonica"                    "Iris_versicolor"
#  [807] "Astelia_fragrans"                 "Astelia_nervosa"
#  [809] "Hesperostipa_comata"              "Hesperostipa_spartea"
#  [811] "Panicum_virgatum"                 "Panicum_capillare"
#  [813] "Cenchrus_americanus"              "Andropogon_gerardii"
#  [815] "Schizachyrium_scoparium"          "Sorghastrum_nutans"
#  [817] "Munroa_christianii-bernardii"     "Bouteloua_gracilis"
#  [819] "Bouteloua_curtipendula"           "Cleistogenes_squarrosa"
#  [821] "Sporobolus_rigidus"               "Sporobolus_heterolepis"
#  [823] "Danthonia_intermedia"             "Festuca_rubra"
#  [825] "Festuca_ovina"                    "Festuca_hallii"
#  [827] "Festuca_christianii-bernardii"    "Lolium_arundinaceum"
#  [829] "Lolium_perenne"                   "Dactylis_glomerata"
#  [831] "Holcus_lanatus"                   "Deschampsia_cespitosa"
#  [833] "Poa_pratensis"                    "Poa_nemoralis"
#  [835] "Poa_cusickii"                     "Phleum_pratense"
#  [837] "Agrostis_scabra"                  "Agrostis_capillaris"
#  [839] "Calamagrostis_canadensis"         "Koeleria_macrantha"
#  [841] "Koeleria_pyramidata"              "Koeleria_vallesiana"
#  [843] "Leymus_chinensis"                 "Agropyron_cristatum"
#  [845] "Elymus_virginicus"                "Elymus_canadensis"
#  [847] "Elymus_lanceolatus"               "Elymus_repens"
#  [849] "Bromus_madritensis"               "Bromus_inermis"
#  [851] "Bromus_erectus"                   "Bromus_catharticus"
#  [853] "Brachypodium_phoenicoides"        "Brachypodium_sylvaticum"
#  [855] "Brachypodium_pinnatum"            "Stipa_krylovii"
#  [857] "Nassella_viridula"                "Stipa_pennata"
#  [859] "Pleioblastus_amarus"              "Wurfbainia_villosa"
#  [861] "Alpinia_japonica"                 "Rhopalostylis_sapida"
#  [863] "Caryota_maxima"                   "Calamus_rhabdocladus"
#  [865] "Smilax_trinervula"                "Smilax_aspera"
#  [867] "Veratrum_nigrum"                  "Toxicoscordion_venenosum"
#  [869] "Dioscorea_nipponica"              "Goniothalamus_griffithii"
#  [871] "Asimina_triloba"                  "Monoon_simiarum"
#  [873] "Pseuduvaria_trimera"              "Mitrephora_tomentosa"
#  [875] "Orophea_creaghii"                 "Unonopsis_rufescens"
#  [877] "Anaxagorea_javanica"              "Magnolia_yuyuanensis"
#  [879] "Magnolia_yunnanensis"             "Magnolia_virginiana"
#  [881] "Magnolia_tripetala"               "Magnolia_stellata"
#  [883] "Magnolia_opipara"                 "Magnolia_macrophylla"
#  [885] "Magnolia_lotungensis"             "Magnolia_kobus"
#  [887] "Magnolia_grandiflora"             "Magnolia_denudata"
#  [889] "Magnolia_championii"              "Magnolia_cavaleriei"
#  [891] "Magnolia_carsonii"                "Magnolia_acuminata"
#  [893] "Magnolia_fulva"                   "Magnolia_champaca"
#  [895] "Magnolia_macclurei"               "Magnolia_baillonii"
#  [897] "Magnolia_balansae"                "Magnolia_ernestii"
#  [899] "Magnolia_chapensis"               "Magnolia_odora"
#  [901] "Magnolia_maudiae"                 "Magnolia_dandyi"
#  [903] "Manglietia_paruicula"             "Liriodendron_chinense"
#  [905] "Liriodendron_tulipifera"          "Knema_erratica"
#  [907] "Horsfieldia_amygdalina"           "Alseodaphnopsis_andersonii"
#  [909] "Ocotea_splendens"                 "Ocotea_scabrella"
#  [911] "Ocotea_rotundata"                 "Ocotea_percurrens"
#  [913] "Ocotea_pedanomischa"              "Ocotea_olivacea"
#  [915] "Ocotea_nigrescens"                "Ocotea_myriantha"
#  [917] "Ocotea_infrafoveolata"            "Ocotea_cuneifolia"
#  [919] "Ocotea_cujumary"                  "Ocotea_boissieriana"
#  [921] "Ocotea_aurantiodora"              "Ocotea_andina"
#  [923] "Ocotea_amazonica"                 "Ocotea_lancifolia"
#  [925] "Ocotea_nigra"                     "Ocotea_argyrophylla"
#  [927] "Ocotea_pauciflora"                "Ocotea_aciphylla"
#  [929] "Aniba_muca"                       "Aniba_hostmanniana"
#  [931] "Aniba_guianensis"                 "Aniba_coto"
#  [933] "Aniba_terminalis"                 "Kubitzkia_mezii"
#  [935] "Licaria_oppositifolia"            "Licaria_macrophylla"
#  [937] "Licaria_hirsuta"                  "Licaria_chrysophylla"
#  [939] "Licaria_guianensis"               "Endlicheria_oreocola"
#  [941] "Endlicheria_macrophylla"          "Endlicheria_arenosa"
#  [943] "Endlicheria_citriodora"           "Endlicheria_longicaudata"
#  [945] "Endlicheria_bracteolata"          "Endlicheria_anomala"
#  [947] "Endlicheria_ruforamula"           "Rhodostemonodaphne_paniculata"
#  [949] "Rhodostemonodaphne_parvifolia"    "Rhodostemonodaphne_crenaticupula"
#  [951] "Aiouea_montana"                   "Cinnamomum_parthenoxylon"
#  [953] "Cinnamomum_austro-sinensis"       "Cinnamomum_glanduliferum"
#  [955] "Cinnamomum_chekiangense"          "Cinnamomum_contractum"
#  [957] "Cinnamomum_iners"                 "Cinnamomum_camphora"
#  [959] "Cinnamomum_micranthum"            "Litsea_mollis"
#  [961] "Litsea_panamanja"                 "Litsea_martabanica"
#  [963] "Litsea_szemaois"                  "Litsea_baviensis"
#  [965] "Litsea_salicifolia"               "Litsea_umbellata"
#  [967] "Litsea_elongata"                  "Litsea_verticillata"
#  [969] "Litsea_glutinosa"                 "Litsea_cubeba"
#  [971] "Litsea_ichangensis"               "Neolitsea_cassia"
#  [973] "Neolitsea_phanerophlebia"         "Actinodaphne_henryi"
#  [975] "Lindera_metcalfiana"              "Lindera_communis"
#  [977] "Lindera_obtusiloba"               "Lindera_benzoin"
#  [979] "Machilus_tenuipilis"              "Machilus_kwangtungensis"
#  [981] "Machilus_breviflora"              "Machilus_robusta"
#  [983] "Machilus_rufipes"                 "Machilus_shweliensis"
#  [985] "Machilus_oculodracontis"          "Machilus_velutina"
#  [987] "Machilus_nanmu"                   "Phoebe_lanceolata"
#  [989] "Phoebe_puwenensis"                "Persea_ferruginea"
#  [991] "Persea_weberbaueri"               "Persea_areolatocostae"
#  [993] "Mezilaurus_ita-uba"               "Sextonia_rubra"
#  [995] "Cryptocarya_brachythyrsa"         "Beilschmiedia_purpurascens"
#  [997] "Beilschmiedia_tarairi"            "Beilschmiedia_tawa"
#  [999] "Cryptocarya_concinna"             "Cryptocarya_acutifolia"
# [1001] "Cryptocarya_yunnanensis"          "Cryptocarya_chinensis"
# [1003] "Hedycarya_arborea"                "Laurelia_novae-zelandiae"
# [1005] "Siparuna_muricata"                "Siparuna_aspera"
# [1007] "Pseudowintera_colorata"           "Hedyosmum_purpurascens"
# [1009] "Hedyosmum_goudotianum"            "Chloranthus_henryi"
# [1011] "Sarcandra_glabra"                 "Ascarina_lucida"
# [1013] "Pectinopitys_ferruginea"          "Podocarpus_laetus"
# [1015] "Podocarpus_gibbsii"               "Podocarpus_neriifolius"
# [1017] "Podocarpus_oleifolius"            "Podocarpus_totara"
# [1019] "Afrocarpus_falcatus"              "Nageia_nagi"
# [1021] "Dacrydium_pectinatum"             "Dacrydium_gracile"
# [1023] "Dacrydium_balansae"               "Dacrydium_cupressinum"
# [1025] "Dacrycarpus_imbricatus"           "Dacrycarpus_dacrydioides"
# [1027] "Phyllocladus_hypophyllus"         "Phyllocladus_trichomanoides"
# [1029] "Lepidothamnus_intermedius"        "Halocarpus_kirkii"
# [1031] "Halocarpus_biformis"              "Prumnopitys_montana"
# [1033] "Prumnopitys_taxifolia"            "Manoao_colensoi"
# [1035] "Araucaria_luxurians"              "Araucaria_rulei"
# [1037] "Agathis_kinabaluensis"            "Agathis_moorei"
# [1039] "Agathis_australis"                "Callitropsis_nootkatensis"
# [1041] "Juniperus_sabina"                 "Juniperus_chinensis"
# [1043] "Juniperus_phoenicea"              "Juniperus_communis"
# [1045] "Calocedrus_decurrens"             "Microbiota_decussata"
# [1047] "Platycladus_orientalis"           "Chamaecyparis_pisifera"
# [1049] "Chamaecyparis_obtusa"             "Thuja_occidentalis"
# [1051] "Taxodium_distichum"               "Cryptomeria_japonica"
# [1053] "Sequoiadendron_giganteum"         "Metasequoia_glyptostroboides"
# [1055] "Cunninghamia_lanceolata"          "Torreya_californica"
# [1057] "Torreya_nucifera"                 "Cephalotaxus_harringtonii"
# [1059] "Taxus_chinensis"                  "Taxus_cuspidata"
# [1061] "Sciadopitys_verticillata"         "Encephalartos_gratus"
# [1063] "Dioon_rzedowskii"                 "Zamia_lucayana"
# [1065] "Cycas_panzhihuaensis"             "Cycas_nathorstii"
# [1067] "Ephedra_fragilis"                 "Ephedra_distachya"
# [1069] "Ginkgo_biloba"                    "Dryopteris_sparsa"
# [1071] "Dryopteris_lepidopoda"            "Polystichum_chilense"
# [1073] "Blechnum_procerum"                "Blechnum_novae-zelandiae"
# [1075] "Blechnum_lanceolatum"             "Blechnum_fluviatilis"
# [1077] "Blechnum_discolor"                "Blechnum_orientale"
# [1079] "Onoclea_sensibilis"               "Matteuccia_struthiopteris"
# [1081] "Athyrium_spinulosum"              "Athyrium_sinense"
# [1083] "Athyrium_monomachii"              "Cystopteris_sudetica"
# [1085] "Pteridium_aquilinum"              "Adiantum_pedatum"
# [1087] "Cyathea_smithii"                  "Alsophila_tricolor"
# [1089] "Alsophila_smithii"                "Sphaeropteris_medullaris"
# [1091] "Dicksonia_squarrosa"              "Cibotium_barometz"
# [1093] "Sticherus_cunninghamii"           "Dicranopteris_pedata"
# [1095] "Dicranopteris_linearis"           "Osmunda_japonica"
# [1097] "Lycopodium_volubile"
#
# $EcM
#   [1] "Arbutus_unedo"                "Coccoloba_manzinellensis"
#   [3] "Coccoloba_excelsa"            "Carpinus_caroliniana"
#   [5] "Carpinus_betulus"             "Carpinus_cordata"
#   [7] "Corylus_ferox"                "Corylus_sieboldiana"
#   [9] "Betula_pendula"               "Betula_dahurica"
#  [11] "Betula_costata"               "Betula_fruticosa"
#  [13] "Betula_utilis"                "Betula_lenta"
#  [15] "Alnus_glutinosa"              "Engelhardia_spicata"
#  [17] "Engelhardia_roxburghiana"     "Engelhardia_serrata"
#  [19] "Carya_glabra"                 "Carya_cordiformis"
#  [21] "Carya_ovata"                  "Quercus_serrata"
#  [23] "Quercus_robur"                "Quercus_mongolica"
#  [25] "Quercus_lowii"                "Quercus_ilex"
#  [27] "Quercus_aliena"               "Quercus_alba"
#  [29] "Quercus_bicolor"              "Quercus_canariensis"
#  [31] "Quercus_faginea"              "Quercus_wutaishanica"
#  [33] "Quercus_suber"                "Quercus_variabilis"
#  [35] "Quercus_asymmetrica"          "Quercus_glauca"
#  [37] "Quercus_oxyodon"              "Quercus_multinervis"
#  [39] "Quercus_coccifera"            "Quercus_palustris"
#  [41] "Quercus_rubra"                "Castanopsis_fabri"
#  [43] "Castanopsis_carlesii"         "Castanopsis_ferox"
#  [45] "Castanopsis_boisii"           "Castanopsis_indica"
#  [47] "Castanopsis_fargesii"         "Castanopsis_echinocarpa"
#  [49] "Castanopsis_fissa"            "Castanopsis_calathiformis"
#  [51] "Castanopsis_wattii"           "Castanopsis_eyrei"
#  [53] "Castanopsis_hystrix"          "Castanopsis_fleuryi"
#  [55] "Castanea_henryi"              "Lithocarpus_rigidus"
#  [57] "Lithocarpus_lampadarius"      "Lithocarpus_confertus"
#  [59] "Lithocarpus_clementianus"     "Lithocarpus_chiungchungensis"
#  [61] "Lithocarpus_elegans"          "Lithocarpus_fohaiensis"
#  [63] "Lithocarpus_fenestratus"      "Lithocarpus_cleistocarpus"
#  [65] "Lithocarpus_variolosus"       "Lithocarpus_bacgiangensis"
#  [67] "Fagus_sylvatica"              "Fagus_grandifolia"
#  [69] "Fagus_engleriana"             "Nothofagus_solandri"
#  [71] "Nothofagus_menziesii"         "Nothofagus_fusca"
#  [73] "Nothofagus_obliqua"           "Tilia_mongolica"
#  [75] "Tilia_mandshurica"            "Tilia_cordata"
#  [77] "Tilia_oliveri"                "Tilia_amurensis"
#  [79] "Tilia_americana"              "Shorea_multiflora"
#  [81] "Shorea_acuminata"             "Shorea_leprosula"
#  [83] "Fumana_thymifolia"            "Cistus_monspeliensis"
#  [85] "Cistus_libanotis"             "Cistus_halimifolius"
#  [87] "Cistus_crispus"               "Cistus_calycinus"
#  [89] "Cistus_albidus"               "Cistus_ladanifer"
#  [91] "Cistus_salviifolius"          "Helianthemum_syriacum"
#  [93] "Helianthemum_apenninum"       "Helianthemum_almeriense"
#  [95] "Helianthemum_oelandicum"      "Pinus_pungens"
#  [97] "Pinus_elliottii"              "Pinus_virginiana"
# ...
#  [849] "Bromus_madritensis"               "Bromus_inermis"
#  [851] "Bromus_erectus"                   "Bromus_catharticus"
#  [853] "Brachypodium_phoenicoides"        "Brachypodium_sylvaticum"
#  [855] "Brachypodium_pinnatum"            "Stipa_krylovii"
#  [857] "Nassella_viridula"                "Stipa_pennata"
#  [859] "Pleioblastus_amarus"              "Wurfbainia_villosa"
#  [861] "Alpinia_japonica"                 "Rhopalostylis_sapida"
#  [863] "Caryota_maxima"                   "Calamus_rhabdocladus"
#  [865] "Smilax_trinervula"                "Smilax_aspera"
#  [867] "Veratrum_nigrum"                  "Toxicoscordion_venenosum"
#  [869] "Dioscorea_nipponica"              "Goniothalamus_griffithii"
#  [871] "Asimina_triloba"                  "Monoon_simiarum"
#  [873] "Pseuduvaria_trimera"              "Mitrephora_tomentosa"
#  [875] "Orophea_creaghii"                 "Unonopsis_rufescens"
#  [877] "Anaxagorea_javanica"              "Magnolia_yuyuanensis"
#  [879] "Magnolia_yunnanensis"             "Magnolia_virginiana"
#  [881] "Magnolia_tripetala"               "Magnolia_stellata"
#  [883] "Magnolia_opipara"                 "Magnolia_macrophylla"
#  [885] "Magnolia_lotungensis"             "Magnolia_kobus"
#  [887] "Magnolia_grandiflora"             "Magnolia_denudata"
#  [889] "Magnolia_championii"              "Magnolia_cavaleriei"
#  [891] "Magnolia_carsonii"                "Magnolia_acuminata"
#  [893] "Magnolia_fulva"                   "Magnolia_champaca"
#  [895] "Magnolia_macclurei"               "Magnolia_baillonii"
#  [897] "Magnolia_balansae"                "Magnolia_ernestii"
#  [899] "Magnolia_chapensis"               "Magnolia_odora"
#  [901] "Magnolia_maudiae"                 "Magnolia_dandyi"
#  [903] "Manglietia_paruicula"             "Liriodendron_chinense"
#  [905] "Liriodendron_tulipifera"          "Knema_erratica"
#  [907] "Horsfieldia_amygdalina"           "Alseodaphnopsis_andersonii"
#  [909] "Ocotea_splendens"                 "Ocotea_scabrella"
#  [911] "Ocotea_rotundata"                 "Ocotea_percurrens"
#  [913] "Ocotea_pedanomischa"              "Ocotea_olivacea"
#  [915] "Ocotea_nigrescens"                "Ocotea_myriantha"
#  [917] "Ocotea_infrafoveolata"            "Ocotea_cuneifolia"
#  [919] "Ocotea_cujumary"                  "Ocotea_boissieriana"
#  [921] "Ocotea_aurantiodora"              "Ocotea_andina"
#  [923] "Ocotea_amazonica"                 "Ocotea_lancifolia"
#  [925] "Ocotea_nigra"                     "Ocotea_argyrophylla"
#  [927] "Ocotea_pauciflora"                "Ocotea_aciphylla"
#  [929] "Aniba_muca"                       "Aniba_hostmanniana"
#  [931] "Aniba_guianensis"                 "Aniba_coto"
#  [933] "Aniba_terminalis"                 "Kubitzkia_mezii"
#  [935] "Licaria_oppositifolia"            "Licaria_macrophylla"
#  [937] "Licaria_hirsuta"                  "Licaria_chrysophylla"
#  [939] "Licaria_guianensis"               "Endlicheria_oreocola"
#  [941] "Endlicheria_macrophylla"          "Endlicheria_arenosa"
#  [943] "Endlicheria_citriodora"           "Endlicheria_longicaudata"
#  [945] "Endlicheria_bracteolata"          "Endlicheria_anomala"
#  [947] "Endlicheria_ruforamula"           "Rhodostemonodaphne_paniculata"
#  [949] "Rhodostemonodaphne_parvifolia"    "Rhodostemonodaphne_crenaticupula"
#  [951] "Aiouea_montana"                   "Cinnamomum_parthenoxylon"
#  [953] "Cinnamomum_austro-sinensis"       "Cinnamomum_glanduliferum"
#  [955] "Cinnamomum_chekiangense"          "Cinnamomum_contractum"
#  [957] "Cinnamomum_iners"                 "Cinnamomum_camphora"
#  [959] "Cinnamomum_micranthum"            "Litsea_mollis"
#  [961] "Litsea_panamanja"                 "Litsea_martabanica"
#  [963] "Litsea_szemaois"                  "Litsea_baviensis"
#  [965] "Litsea_salicifolia"               "Litsea_umbellata"
#  [967] "Litsea_elongata"                  "Litsea_verticillata"
#  [969] "Litsea_glutinosa"                 "Litsea_cubeba"
#  [971] "Litsea_ichangensis"               "Neolitsea_cassia"
#  [973] "Neolitsea_phanerophlebia"         "Actinodaphne_henryi"
#  [975] "Lindera_metcalfiana"              "Lindera_communis"
#  [977] "Lindera_obtusiloba"               "Lindera_benzoin"
#  [979] "Machilus_tenuipilis"              "Machilus_kwangtungensis"
#  [981] "Machilus_breviflora"              "Machilus_robusta"
#  [983] "Machilus_rufipes"                 "Machilus_shweliensis"
#  [985] "Machilus_oculodracontis"          "Machilus_velutina"
#  [987] "Machilus_nanmu"                   "Phoebe_lanceolata"
#  [989] "Phoebe_puwenensis"                "Persea_ferruginea"
#  [991] "Persea_weberbaueri"               "Persea_areolatocostae"
#  [993] "Mezilaurus_ita-uba"               "Sextonia_rubra"
#  [995] "Cryptocarya_brachythyrsa"         "Beilschmiedia_purpurascens"
#  [997] "Beilschmiedia_tarairi"            "Beilschmiedia_tawa"
#  [999] "Cryptocarya_concinna"             "Cryptocarya_acutifolia"
# [1001] "Cryptocarya_yunnanensis"          "Cryptocarya_chinensis"
# [1003] "Hedycarya_arborea"                "Laurelia_novae-zelandiae"
# [1005] "Siparuna_muricata"                "Siparuna_aspera"
# [1007] "Pseudowintera_colorata"           "Hedyosmum_purpurascens"
# [1009] "Hedyosmum_goudotianum"            "Chloranthus_henryi"
# [1011] "Sarcandra_glabra"                 "Ascarina_lucida"
# [1013] "Pectinopitys_ferruginea"          "Podocarpus_laetus"
# [1015] "Podocarpus_gibbsii"               "Podocarpus_neriifolius"
# [1017] "Podocarpus_oleifolius"            "Podocarpus_totara"
# [1019] "Afrocarpus_falcatus"              "Nageia_nagi"
# [1021] "Dacrydium_pectinatum"             "Dacrydium_gracile"
# [1023] "Dacrydium_balansae"               "Dacrydium_cupressinum"
# [1025] "Dacrycarpus_imbricatus"           "Dacrycarpus_dacrydioides"
# [1027] "Phyllocladus_hypophyllus"         "Phyllocladus_trichomanoides"
# [1029] "Lepidothamnus_intermedius"        "Halocarpus_kirkii"
# [1031] "Halocarpus_biformis"              "Prumnopitys_montana"
# [1033] "Prumnopitys_taxifolia"            "Manoao_colensoi"
# [1035] "Araucaria_luxurians"              "Araucaria_rulei"
# [1037] "Agathis_kinabaluensis"            "Agathis_moorei"
# [1039] "Agathis_australis"                "Callitropsis_nootkatensis"
# [1041] "Juniperus_sabina"                 "Juniperus_chinensis"
# [1043] "Juniperus_phoenicea"              "Juniperus_communis"
# [1045] "Calocedrus_decurrens"             "Microbiota_decussata"
# [1047] "Platycladus_orientalis"           "Chamaecyparis_pisifera"
# [1049] "Chamaecyparis_obtusa"             "Thuja_occidentalis"
# [1051] "Taxodium_distichum"               "Cryptomeria_japonica"
# [1053] "Sequoiadendron_giganteum"         "Metasequoia_glyptostroboides"
# [1055] "Cunninghamia_lanceolata"          "Torreya_californica"
# [1057] "Torreya_nucifera"                 "Cephalotaxus_harringtonii"
# [1059] "Taxus_chinensis"                  "Taxus_cuspidata"
# [1061] "Sciadopitys_verticillata"         "Encephalartos_gratus"
# [1063] "Dioon_rzedowskii"                 "Zamia_lucayana"
# [1065] "Cycas_panzhihuaensis"             "Cycas_nathorstii"
# [1067] "Ephedra_fragilis"                 "Ephedra_distachya"
# [1069] "Ginkgo_biloba"                    "Dryopteris_sparsa"
# [1071] "Dryopteris_lepidopoda"            "Polystichum_chilense"
# [1073] "Blechnum_procerum"                "Blechnum_novae-zelandiae"
# [1075] "Blechnum_lanceolatum"             "Blechnum_fluviatilis"
# [1077] "Blechnum_discolor"                "Blechnum_orientale"
# [1079] "Onoclea_sensibilis"               "Matteuccia_struthiopteris"
# [1081] "Athyrium_spinulosum"              "Athyrium_sinense"
# [1083] "Athyrium_monomachii"              "Cystopteris_sudetica"
# [1085] "Pteridium_aquilinum"              "Adiantum_pedatum"
# [1087] "Cyathea_smithii"                  "Alsophila_tricolor"
# [1089] "Alsophila_smithii"                "Sphaeropteris_medullaris"
# [1091] "Dicksonia_squarrosa"              "Cibotium_barometz"
# [1093] "Sticherus_cunninghamii"           "Dicranopteris_pedata"
# [1095] "Dicranopteris_linearis"           "Osmunda_japonica"
# [1097] "Lycopodium_volubile"
#
# $EcM
#   [1] "Arbutus_unedo"                "Coccoloba_manzinellensis"
#   [3] "Coccoloba_excelsa"            "Carpinus_caroliniana"
#   [5] "Carpinus_betulus"             "Carpinus_cordata"
#   [7] "Corylus_ferox"                "Corylus_sieboldiana"
#   [9] "Betula_pendula"               "Betula_dahurica"
#  [11] "Betula_costata"               "Betula_fruticosa"
#  [13] "Betula_utilis"                "Betula_lenta"
#  [15] "Alnus_glutinosa"              "Engelhardia_spicata"
#  [17] "Engelhardia_roxburghiana"     "Engelhardia_serrata"
#  [19] "Carya_glabra"                 "Carya_cordiformis"
#  [21] "Carya_ovata"                  "Quercus_serrata"
#  [23] "Quercus_robur"                "Quercus_mongolica"
#  [25] "Quercus_lowii"                "Quercus_ilex"
#  [27] "Quercus_aliena"               "Quercus_alba"
#  [29] "Quercus_bicolor"              "Quercus_canariensis"
#  [31] "Quercus_faginea"              "Quercus_wutaishanica"
#  [33] "Quercus_suber"                "Quercus_variabilis"
#  [35] "Quercus_asymmetrica"          "Quercus_glauca"
#  [37] "Quercus_oxyodon"              "Quercus_multinervis"
#  [39] "Quercus_coccifera"            "Quercus_palustris"
#  [41] "Quercus_rubra"                "Castanopsis_fabri"
#  [43] "Castanopsis_carlesii"         "Castanopsis_ferox"
#  [45] "Castanopsis_boisii"           "Castanopsis_indica"
#  [47] "Castanopsis_fargesii"         "Castanopsis_echinocarpa"
#  [49] "Castanopsis_fissa"            "Castanopsis_calathiformis"
#  [51] "Castanopsis_wattii"           "Castanopsis_eyrei"
#  [53] "Castanopsis_hystrix"          "Castanopsis_fleuryi"
#  [55] "Castanea_henryi"              "Lithocarpus_rigidus"
#  [57] "Lithocarpus_lampadarius"      "Lithocarpus_confertus"
#  [59] "Lithocarpus_clementianus"     "Lithocarpus_chiungchungensis"
#  [61] "Lithocarpus_elegans"          "Lithocarpus_fohaiensis"
#  [63] "Lithocarpus_fenestratus"      "Lithocarpus_cleistocarpus"
#  [65] "Lithocarpus_variolosus"       "Lithocarpus_bacgiangensis"
#  [67] "Fagus_sylvatica"              "Fagus_grandifolia"
#  [69] "Fagus_engleriana"             "Nothofagus_solandri"
#  [71] "Nothofagus_menziesii"         "Nothofagus_fusca"
#  [73] "Nothofagus_obliqua"           "Tilia_mongolica"
#  [75] "Tilia_mandshurica"            "Tilia_cordata"
#  [77] "Tilia_oliveri"                "Tilia_amurensis"
#  [79] "Tilia_americana"              "Shorea_multiflora"
#  [81] "Shorea_acuminata"             "Shorea_leprosula"
#  [83] "Fumana_thymifolia"            "Cistus_monspeliensis"
#  [85] "Cistus_libanotis"             "Cistus_halimifolius"
#  [87] "Cistus_crispus"               "Cistus_calycinus"
#  [89] "Cistus_albidus"               "Cistus_ladanifer"
#  [91] "Cistus_salviifolius"          "Helianthemum_syriacum"
#  [93] "Helianthemum_apenninum"       "Helianthemum_almeriense"
#  [95] "Helianthemum_oelandicum"      "Pinus_pungens"
#  [97] "Pinus_elliottii"              "Pinus_virginiana"
#  [99] "Pinus_sylvestris"             "Pinus_nigra"
# [101] "Pinus_resinosa"               "Pinus_massoniana"
# [103] "Pinus_tabuliformis"           "Pinus_pinea"
# [105] "Pinus_armandii"               "Pinus_koraiensis"
# [107] "Pinus_pumila"                 "Pinus_strobus"
# [109] "Picea_koraiensis"             "Picea_meyeri"
# [111] "Picea_abies"                  "Picea_wilsonii"
# [113] "Larix_gmelinii"               "Larix_decidua"
# [115] "Larix_kaempferi"              "Pseudotsuga_menziesii"
# [117] "Abies_nephrolepis"            "Abies_alba"
# [119] "Tsuga_canadensis"             "Cedrus_libani"
# [121] "Gnetum_gnemon"
#
# $EcMAM
#  [1] "Acacia_mangium"          "Acacia_auriculiformis"
#  [3] "Acacia_crassicarpa"      "Salix_atrocinerea"
#  [5] "Salix_abscondita"        "Salix_viminalis"
#  [7] "Salix_caprea"            "Populus_grandidentata"
#  [9] "Populus_alba"            "Populus_tremula"
# [11] "Populus_tremuloides"     "Populus_cathayana"
# [13] "Populus_suaveolens"      "Populus_trichocarpa"
# [15] "Populus_deltoides"       "Eucalyptus_urophylla"
# [17] "Leptospermum_scoparium"  "Kunzea_ericoides"
# [19] "Tristaniopsis_obovata"   "Tristaniopsis_elliptica"
#
# $ErM
# [1] "Erica_arborea"            "Erica_scoparia"
# [3] "Calluna_vulgaris"         "Rhododendron_hypoglaucum"
# [5] "Rhododendron_ponticum"    "Vaccinium_mandarinorum"
# [7] "Vaccinium_corymbosum"     "Leptecophylla_juniperina"
# [9] "Dracophyllum_longifolium"
#
# $NM
#  [1] "Orthocarpus_luteus"    "Lupinus_perennis"      "Erysimum_inconspicuum"
#  [4] "Draba_nemorosa"        "Berteroa_incana"       "Lepidium_densiflorum"
#  [7] "Descurainia_sophia"    "Knightia_excelsa"      "Helicia_formosana"
# [10] "Hakea_varia"           "Hakea_tuberculata"     "Hakea_oldfieldii"
# [13] "Hakea_cyclocarpa"      "Hakea_lissocarpha"     "Hakea_linearis"
# [16] "Hakea_ceratophylla"
#
# $NMAM
#  [1] "Lamium_album"           "Galium_boreale"         "Galium_aparine"
#  [4] "Corythophora_alta"      "Arenaria_serpyllifolia" "Cerastium_arvense"
#  [7] "Chenopodium_album"      "Rumex_acetosella"       "Fallopia_convolvulus"
# [10] "Armeria_velutina"       "Osyris_alba"            "Myriocarpa_stipitata"
# [13] "Oreocnide_frutescens"   "Myrica_pubescens"       "Heuchera_richardsonii"
# [16] "Astilbe_rivularis"      "Astilbe_rubra"          "Caltha_palustris"
# [19] "Eragrostis_trichodes"   "Puccinellia_rupestris"  "Phalaris_arundinacea"
# [22] "Carex_tibetikobresia"   "Carex_pseuduncinoides"  "Carex_korshinskyi"
# [25] "Carex_humulis"          "Carex_filifolia"        "Carex_lasiocarpa"
# [28] "Carex_atrofusca"        "Carex_flacca"           "Carex_coriophora"
# [31] "Carex_obtusata"         "Gahnia_xanthocarpa"     "Gahnia_procera"
# [34] "Sassafras_albidum"      "Piper_arboreum"         "Asplenium_bulbiferum"
# [37] "Equisetum_hyemale"      "Equisetum_pratense"

# %%
# Out:
# $AM
# [1] 1097
#
# $EcM
# [1] 121
#
# $EcMAM
# [1] 20
#
# $ErM
# [1] 9
#
# $NM
# [1] 16
#
# $NMAM
# [1] 38

# %%
ggplot(aes(x = F00679, y = F00709, group = state, bg = I(colour)), data = traits) + 
    geom_point(pch = 21, color = "black") +
    stat_smooth(method = "lm", color = "black", linetype = "solid") +
    theme_bw()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
ggplot(aes(x = F00709, y = F00727, group = state, bg = I(colour)), data = traits) + 
    geom_point(pch = 21, color = "black") +
    stat_smooth(method = "lm") +
    theme_bw()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
#------------
# SRL & RD
#------------

lmod <- lm(F00727 ~ F00679 + state, data = traits)
plmod <- phylolm::phylolm(F00727 ~ F00679 + state, data = traits, model = "lambda", phy = tree)#, lower.bound = list(alpha=1e-10), upper.bound = list(alpha=10))

# png(filename = "../../plots/SRL-RD_FRED4.png", width = 10, height = 10, units = "in", res = 500)
par(mar=c(3, 3, 1, 1))
plot(F00727 ~ F00679, data = traits, xlab = "RD", ylab = "SRL", mgp=c(1.85, 0.7, 0), frame.plot = TRUE, pch = 21, bg = STATE_COLOURS[traits$state], cex.lab = 1.5, cex.axis = 1.5)
grid()
abline(lmod, col = "red")


# abline(plmod, col = "blue")
# legend(x = c(-2.5, -2.0), y = c(1, 1.2), legend = names(STATE_COLOURS), pt.bg = STATE_COLOURS, pch = 21, pt.cex = 3., horiz = FALSE, ncol = 2, bty = "n", y.intersp = 1.4, x.intersp = 1.2, text.width = 0.2)
# dev.off()
# Out:
# Warning message in abline(lmod, col = "red"):
# "only using the first two of 7 regression coefficients"
# plot without title

# %%
summary(lmod)
# Out:
# Call:
# lm(formula = F00727 ~ F00679, data = traits)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.85163 -0.43048 -0.06405  0.34489  3.06180
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.67507    0.04464   37.53   <2e-16 ***
# F00679      -1.88414    0.04391  -42.91   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.7354 on 1299 degrees of freedom
# Multiple R-squared:  0.5863,	Adjusted R-squared:  0.586
# F-statistic:  1841 on 1 and 1299 DF,  p-value: < 2.2e-16

# %%
summary(plmod)
# Out:
# Call:
# phylolm::phylolm(formula = F00727 ~ F00679, data = traits, phy = tree,
#     model = "lambda")
#
#    AIC logLik
#   2279  -1135
#
# Raw residuals:
#      Min       1Q   Median       3Q      Max
# -2.98749 -0.71656 -0.37070  0.08457  2.72704
#
# Mean tip height: 400.7877
# Parameter estimate(s) using ML:
# lambda : 0.8531686
# sigma2: 0.00351361
#
# Coefficients:
#              Estimate    StdErr  t.value   p.value
# (Intercept)  2.058079  0.470378   4.3754 1.309e-05 ***
# F00679      -1.772702  0.041431 -42.7868 < 2.2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-squared: 0.5849	Adjusted R-squared: 0.5846
#
# Note: p-values and R-squared are conditional on lambda=0.8531686.

# %%
#------------
# SRL & RTD
#------------

lmod <- lm(F00727 ~ F00709, data = traits)
plmod <- phylolm::phylolm(F00727 ~ F00709, data = traits, model = "lambda", phy = tree)#, lower.bound = list(alpha=1e-10), upper.bound = list(alpha=10))

# png(filename = "../../plots/SRL-RTD_FRED4.png", width = 10, height = 10, units = "in", res = 500)
par(mar=c(3, 3, 1, 1))
plot(F00727 ~ F00709, data = traits, xlab = "RTD", ylab = "SRL", mgp=c(1.85, 0.7, 0), frame.plot = TRUE, pch = 21, bg = STATE_COLOURS[traits$state], cex.lab = 1.5, cex.axis = 1.5)
grid()
abline(lmod, col = "red")
abline(plmod, col = "blue")
# legend("bottomleft", legend = names(STATE_COLOURS), pt.bg = STATE_COLOURS, pch = 21, pt.cex = 1.5, horiz = FALSE, ncol = 2, bty = "n", y.intersp = 1.25, x.intersp = 0.75, text.width = 0.2)
dev.off()
# Out:
# null device
#           1
# plot without title

# %%
summary(lmod)
# Out:
# Call:
# lm(formula = F00727 ~ F00709, data = traits)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.03060 -0.69552 -0.05758  0.61428  2.88374
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.00493    0.05812   34.50   <2e-16 ***
# F00709      -1.03227    0.03920  -26.33   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9233 on 1299 degrees of freedom
# Multiple R-squared:  0.348,	Adjusted R-squared:  0.3475
# F-statistic: 693.4 on 1 and 1299 DF,  p-value: < 2.2e-16

# %%
summary(plmod)
# Out:
# Call:
# phylolm::phylolm(formula = F00727 ~ F00709, data = traits, phy = tree,
#     model = "lambda")
#
#    AIC logLik
#   3011  -1502
#
# Raw residuals:
#     Min      1Q  Median      3Q     Max
# -1.6976 -0.4668  0.1596  0.8618  3.0418
#
# Mean tip height: 400.7877
# Parameter estimate(s) using ML:
# lambda : 0.8144812
# sigma2: 0.005262584
#
# Coefficients:
#              Estimate    StdErr  t.value   p.value
# (Intercept)  1.930415  0.569325   3.3907 0.0007181 ***
# F00709      -0.911692  0.041514 -21.9613 < 2.2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-squared: 0.2708	Adjusted R-squared: 0.2702
#
# Note: p-values and R-squared are conditional on lambda=0.8144812.

# %%
#------------
# RD & RTD
#------------

lmod <- lm(F00709 ~ F00679, data = traits)
plmod <- phylolm::phylolm(F00709 ~ F00679, data = traits, model = "lambda", phy = tree)#, lower.bound = list(alpha=1e-10), upper.bound = list(alpha=10))

png(filename = "../../plots/RTD-RD_FRED4.png", width = 10, height = 10, units = "in", res = 500)
par(mar=c(3, 3, 1, 1))
plot(F00709 ~ F00679, data = traits, xlab = "RD", ylab = "RTD", mgp=c(1.85, 0.7, 0), frame.plot = TRUE, pch = 21, bg = STATE_COLOURS[traits$state], cex.lab = 1.5, cex.axis = 1.5)
grid()
# abline(lmod, col = "red")
# abline(plmod, col = "blue")
# legend("bottomleft", legend = names(STATE_COLOURS), pt.bg = STATE_COLOURS, pch = 21, pt.cex = 1.5, horiz = FALSE, ncol = 2, bty = "n", y.intersp = 1.25, x.intersp = 0.75, text.width = 0.2)
dev.off()
# Out:
# pdf
#   2

# %%
summary(lmod)
# Out:
# Call:
# lm(formula = F00709 ~ F00679, data = traits)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.63557 -0.35487  0.08587  0.44516  1.88227
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.30082    0.03965 -32.807   <2e-16 ***
# F00679       0.03337    0.03901   0.855    0.392
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.6533 on 1299 degrees of freedom
# Multiple R-squared:  0.000563,	Adjusted R-squared:  -0.0002064
# F-statistic: 0.7317 on 1 and 1299 DF,  p-value: 0.3925

# %%
summary(plmod)
# Out:
# Call:
# phylolm::phylolm(formula = F00709 ~ F00679, data = traits, phy = tree,
#     model = "lambda")
#
#    AIC logLik
# 1960.5 -976.2
#
# Raw residuals:
#      Min       1Q   Median       3Q      Max
# -2.25958  0.03592  0.48359  0.84316  2.21827
#
# Mean tip height: 400.7877
# Parameter estimate(s) using ML:
# lambda : 0.8348878
# sigma2: 0.002542712
#
# Coefficients:
#              Estimate    StdErr t.value   p.value
# (Intercept) -1.762623  0.397198 -4.4376 9.865e-06 ***
# F00679      -0.043338  0.036674 -1.1817    0.2375
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-squared: 0.001074	Adjusted R-squared: 0.0003048
#
# Note: p-values and R-squared are conditional on lambda=0.8348878.

# %% [raw]
# # plot everything together
# #-----------------------------
#
# lmod_SRL_RD <- lm(F00727 ~ F00679, data = traits)
# lmod_SRL_RTD <- lm(F00727 ~ F00709, data = traits)
# lmod_RD_RTD <- lm(F00679 ~ F00709, data = traits)
#
# plmod_SRL_RD <- phylolm::phylolm(F00727 ~ F00679, data = traits, model = "lambda", phy = tree, lower.bound = list(alpha=1e-10), upper.bound = list(alpha=10))
# plmod_SRL_RTD <- phylolm::phylolm(F00727 ~ F00709, data = traits, model = "lambda", phy = tree, lower.bound = list(alpha=1e-10), upper.bound = list(alpha=10))
# plmod_RD_RTD <- phylolm::phylolm(F00679 ~ F00709, data = traits, model = "lambda", phy = tree, lower.bound = list(alpha=1e-10), upper.bound = list(alpha=10))
#
# png(filename = "../../plots/pairwise-regression.png", width = 18, height = 7, units = "in", res = 600, type = "cairo-png")
# grid_layout <- matrix(c(1, 2, 3, 4, 4, 4), nrow = 2, ncol = 3, byrow = TRUE) # https://stackoverflow.com/questions/10389967/common-legend-for-multiple-plots-in-r
# layout(mat = grid_layout, heights = c(0.95, 0.05))
#
# par(mar = c(3, 3, 1, 1))
#
# # panel.first=grid() is lazy evaluatyed and doesn't work with plots using the formula method
# plot(F00727 ~ F00679, data = traits, xlab = "RD", ylab = "SRL", mgp=c(1.85, 0.7, 0), frame.plot = TRUE, pch = 21, bg = STATE_COLOURS[traits$state])
# grid()
# abline(lmod_SRL_RD, col = "red")
# abline(plmod_SRL_RD, col = "blue")
#
# plot(F00727 ~ F00709, data = traits, xlab = "RTD", ylab = "SRL", mgp=c(1.85, 0.7, 0), frame.plot = TRUE, pch = 21, bg = STATE_COLOURS[traits$state])
# grid()
# abline(lmod_SRL_RTD, col = "red")
# abline(plmod_SRL_RTD, col = "blue")
#
# plot(F00679 ~ F00709, data = traits, xlab = "RTD", ylab = "SRL", mgp=c(1.85, 0.7, 0), frame.plot = TRUE, pch = 21, bg = STATE_COLOURS[traits$state])
# grid()
# # abline(lmod_RD_RTD, col = "red")
# # abline(plmod_RD_RTD, col = "blue")
#
# par(mar = c(0, 0, 1, 0))
# plot(1,  type = "n", axes=FALSE, xlab="", ylab="")
# legend("bottomleft", legend = names(STATE_COLOURS), pt.bg = STATE_COLOURS, pch = 21, pt.cex = 1.5, horiz = FALSE, ncol = 6, bty = "n", x.intersp = 0.75)#, text.width = 0.02)
# dev.off()

# %%
# evern after accounting for phylogenetic relatedness, RD ~ SRL and SRL ~ RTD trait pairs show significant relationships
# so, next step, calculate how much phylogenetic signal is present in our continuous traits?? because the above could be a result of our dataset having little to no phylogenetic signal???

# %%
# INVESTIGATE THE PHYLOGENETIC SIGNAL IN THE CONTINUOUS TRAITS
# lambda method is best suited for detecting phylogenetic signals lesser (weaker) than that's expected under a BM model - not good for signals stronger than that of a BM model
# lambda < 1 corresponds to less phylogenetic signal than expected under a BM model

# all the continuous traits have already been log transformed
physig_srl <- phytools::phylosig(tree = tree, method = "lambda", x = setNames(traits$F00727, nm = rownames(traits)), test = TRUE)
physig_rd <- phytools::phylosig(tree = tree, method = "lambda", x = setNames(traits$F00679, nm = rownames(traits)), test = TRUE)
physig_rtd <- phytools::phylosig(tree = tree, method = "lambda", x = setNames(traits$F00709, nm = rownames(traits)), test = TRUE)

# %%
# all the three traits have pretty similar lambda values and all of them are closer to 1.0 than to 0.0
# this tells us that we can reject the null hypothesis that lambda = 0 (with reference to the p values)
# LR stands for Likelihood Ratio

# %%
physig_srl
# Out:
# Phylogenetic signal lambda : 0.833651
# logL(lambda) : -1702.85
# LR(lambda=0) : 623.519
# P-value (based on LR test) : 1.2835e-137

# %%
physig_rd
# Out:
# Phylogenetic signal lambda : 0.828158
# logL(lambda) : -616.319
# LR(lambda=0) : 466.128
# P-value (based on LR test) : 2.23079e-103

# %%
physig_rtd
# Out:
# Phylogenetic signal lambda : 0.831478
# logL(lambda) : -966.91
# LR(lambda=0) : 630.01
# P-value (based on LR test) : 4.97377e-139

# %%
# now test for the hypothesis that lambda = 1 (the phylogenetic signal observed is no more significant than what could be generated by a stochastic BM process)
# the $lik attribute of a phylosig object is the function used for its optimization

# likelihood of lambda = 1 is physig_srl$lik(1.00)
# then compare it to the MLE of lambda
lr_srl <- -2 * (physig_srl$lik(1.00) - physig_srl$logL) # page 97 - Phylogenetic Comparative Methods in R

# then compute the p statistic for our LR by comparing it to a chi squared dist with 1 degrees of freedom
pchisq(q = lr_srl, df = 1, lower.tail = FALSE) # p = 0, so we can reject the null hypothesis, which in this case is lambda = 1
# Out:
# [1] 0

# %%
# for RTD
pchisq(q = -2 * (physig_rtd$lik(1.00) - physig_rtd$logL), df = 1, lower.tail = FALSE)
# Out:
# [1] 0

# %%
# for RD
pchisq(q = -2 * (physig_rd$lik(1.00) - physig_rd$logL), df = 1, lower.tail = FALSE)
# Out:
# [1] 0

# %%
# in conclusion; lambda != 1 and lambda != 0 for all the three continuous traits according to Pagel's lambda test

# %%
# now do Bloomberg's K test for all the three traits => most papers report both not just one
# Bloomberk's K is a normalized ratio of comparing variance among clades to variance within clades
# for a simple BM model of evolution, Bloomberg's K must be 1.00

physig_srl <- phytools::phylosig(tree = tree, method = "K", x = setNames(traits$F00727, nm = rownames(traits)), test = TRUE, nsim = 10000)
physig_rd <- phytools::phylosig(tree = tree, method = "K", x = setNames(traits$F00679, nm = rownames(traits)), test = TRUE, nsim = 10000)
physig_rtd <- phytools::phylosig(tree = tree, method = "K", x = setNames(traits$F00709, nm = rownames(traits)), test = TRUE, nsim = 10000)

# %%
physig_rd
# Out:
# Phylogenetic signal K : 0.0234281
# P-value (based on 10000 randomizations) : 1e-04

# %%
physig_srl
# Out:
# Phylogenetic signal K : 0.0228481
# P-value (based on 10000 randomizations) : 1e-04

# %%
physig_rtd
# Out:
# Phylogenetic signal K : 0.0319059
# P-value (based on 10000 randomizations) : 1e-04

# %%
# in our case, all the three traits show a K that is less than expected from a BM model of evolution

# %%
# for an explanation on non BM models - https://lukejharmon.github.io/pcm/chapter6_beyondbm/
# page 100 of Phylogenetic Comparative Methods in R
# PAY ATTENTION TO THE WARNING MESSAGES HERE!!!!!!!!

tm <- Sys.time()

SRL_model_fits <- list()
RD_model_fits <- list()
RTD_model_fits <- list()

for (m in GEIGER_FITCONTINUOUS_MODEL_OPTIONS) {
    SRL_model_fits[[m]] <- geiger::fitContinuous(phy = tree, dat = traits["F00727"], model = m)
    RD_model_fits[[m]] <- geiger::fitContinuous(phy = tree, dat = traits["F00679"], model = m)
    RTD_model_fits[[m]] <- geiger::fitContinuous(phy = tree, dat = traits["F00709"], model = m)
    print(paste0("all ", m, " fits done!"))
}

tm <- Sys.time() - tm

save(SRL_model_fits, RD_model_fits, RTD_model_fits, file = "../../data/chapter2/rdata/SRL_RD_RTD_geiger_fitContinuous.RData")
# Out:
# [1] "all BM fits done!"
# [1] "all OU fits done!"
# Warning message in geiger::fitContinuous(phy = tree, dat = traits["F00679"], model = m):
# "
# Parameter estimates appear at bounds:
# 	a"
# [1] "all EB fits done!"
# [1] "all rate_trend fits done!"
# [1] "all lambda fits done!"
# [1] "all kappa fits done!"
# [1] "all delta fits done!"
# [1] "all mean_trend fits done!"
# [1] "all white fits done!"

# %%
tm # not bad at all :)
# Out:
# Time difference of 6.48128 mins

# %%
# inspect the EB models 

SRL_model_fits[["EB"]]$opt # alpha is near zero - in this case EB models regress to a constant rate BM model, this does not need to be corrected since this is not an error!
# page 101 - Phylogenetic Comparative Methods in R
# Out:
# $a
# [1] -1.000012e-06
#
# $sigsq
# [1] 0.1739684
#
# $z0
# [1] 3.578437
#
# $lnL
# [1] -2595.165
#
# $method
# [1] "subplex"
#
# $k
# [1] 3
#
# $aic
# [1] 5196.33
#
# $aicc
# [1] 5196.349

# %%
load("../../data/chapter2/rdata/SRL_RD_RTD_geiger_fitContinuous.RData") # reusing the serialized model fits

# for all the three continuous traits lambda seems to be the best model, followed by kappa and then OU??????

# AICc table
aicc_table <- cbind(
    SRL = mapply(SRL_model_fits, FUN = function(m) m$opt$aicc),
    RD = mapply(RD_model_fits, FUN = function(m) m$opt$aicc),
    RTD = mapply(RTD_model_fits, FUN = function(m) m$opt$aicc)
)

aicc_table
# Out:
#            SRL      RD       RTD
# BM         5194.320 2856.343 3753.738
# OU         3929.309 1673.022 2363.545
# EB         5196.349 2858.372 3755.767
# rate_trend 5142.831 2805.895 3701.959
# lambda     3411.727 1238.656 1939.839
# kappa      3541.948 1414.503 2097.651
# delta      5092.885 2757.039 3651.684
# mean_trend 5196.329 2858.353 3755.747
# white      4033.236 1702.775 2567.840

# %%
#

# %%
RD_model_fits[["lambda"]]$opt
# Out:
# $lambda
# [1] 0.8281666
#
# $sigsq
# [1] 0.00142289
#
# $z0
# [1] -0.8023254
#
# $lnL
# [1] -616.3189
#
# $method
# [1] "subplex"
#
# $k
# [1] 3
#
# $aic
# [1] 1238.638
#
# $aicc
# [1] 1238.656

# %%
SRL_model_fits[["lambda"]]$opt
# Out:
# $lambda
# [1] 0.833639
#
# $sigsq
# [1] 0.007730035
#
# $z0
# [1] 3.560545
#
# $lnL
# [1] -1702.854
#
# $method
# [1] "L-BFGS-B"
#
# $k
# [1] 3
#
# $aic
# [1] 3411.708
#
# $aicc
# [1] 3411.727

# %%
RTD_model_fits[["lambda"]]$opt
# Out:
# $lambda
# [1] 0.8314678
#
# $sigsq
# [1] 0.002471727
#
# $z0
# [1] -1.710555
#
# $lnL
# [1] -966.9103
#
# $method
# [1] "L-BFGS-B"
#
# $k
# [1] 3
#
# $aic
# [1] 1939.821
#
# $aicc
# [1] 1939.839

# %%
# branch length transformation

# %%
lapply(c(RD_model_fits["lambda"], SRL_model_fits["lambda"], RTD_model_fits["lambda"]), FUN = function(m) m$opt$lambda)
# Out:
# $lambda
# [1] 0.8281666
#
# $lambda
# [1] 0.833639
#
# $lambda
# [1] 0.8314678

# %%
lapply(c(RD_model_fits["lambda"], SRL_model_fits["lambda"], RTD_model_fits["lambda"]), FUN = function(m) m$opt$lambda) |> as.numeric() |> mean()
# Out:
# [1] 0.8310911

# %%
transformed_tree <- geiger:::rescale.phylo(x = tree, model = "lambda", lambda = 0.831091127072489)

# %%
options(repr.plot.width = 20, repr.plot.height = 10)
par(mfcol = c(1, 2))
ape::plot.phylo(tree, type = "fan", show.tip.label = FALSE)
ape::plot.phylo(transformed_tree, type = "fan", show.tip.label = FALSE) # interesting
# Out:
# plot without title

# %%
# AIC weights table

cbind(
    SRL = aic.w(mapply(SRL_model_fits, FUN = function(m) AIC(m))),
    RD = aic.w(mapply(RD_model_fits, FUN = function(m) AIC(m))),
    RTD = aic.w(mapply(RTD_model_fits, FUN = function(m) AIC(m)))
)
# Out:
#            SRL           RD            RTD
# BM          0.000000e+00  0.000000e+00  0.000000e+00
# OU         4.059008e-113  4.771765e-95  9.851911e-93
# EB          0.000000e+00  0.000000e+00  0.000000e+00
# rate_trend  0.000000e+00  0.000000e+00  0.000000e+00
# lambda      1.000000e+00  1.000000e+00  1.000000e+00
# kappa       5.281734e-29  6.536003e-39  5.388475e-35
# delta       0.000000e+00  0.000000e+00  0.000000e+00
# mean_trend  0.000000e+00  0.000000e+00  0.000000e+00
# white      1.093630e-135 1.644340e-101 4.259908e-137

# %%
aicc_table
# Out:
#            SRL      RD       RTD
# BM         5194.320 2856.343 3753.738
# OU         3929.309 1673.022 2363.545
# EB         5196.349 2858.372 3755.767
# rate_trend 5142.831 2805.895 3701.959
# lambda     3411.727 1238.656 1939.839
# kappa      3541.948 1414.503 2097.651
# delta      5092.885 2757.039 3651.684
# mean_trend 5196.329 2858.353 3755.747
# white      4033.236 1702.775 2567.840

# %%
fit_rd <- geiger::fitContinuous(phy = tree, dat = traits["F00679"], model = "OU")$opt
fit_srl <- geiger::fitContinuous(phy = tree, dat = traits["F00727"], model = "OU")$opt
fit_rtd <- geiger::fitContinuous(phy = tree, dat = traits["F00709"], model = "OU")$opt

# %%
rbind(fit_rd, fit_srl, fit_rtd) |> t() |> as.data.frame()
# Out:
#        fit_rd     fit_srl   fit_rtd
# alpha  0.2283605  0.2347242 0.5055475
# sigsq  0.1046208  0.6145754 0.3889756
# z0     -0.9270203 3.377086  -1.298271
# lnL    -821.7603  -1957.404 -1194.053
# method L-BFGS-B   L-BFGS-B  L-BFGS-B
# k      3          3         3
# aic    1649.521   3920.807  2394.105
# aicc   1649.539   3920.826  2394.124

# %% [markdown]
# # ___`Rphylopars`___
# ----------------------------

# %%
# apparently fitting OU models in brms can be tricky - let's try Rphylopars - which allows multivariate OU models
# the trait data should have species as the first column is also species names, followed by the continuous traits - the name of the first column must be "species"
# with duplicate entries (for within species variation) - we cannot have binominal names as the rownames

fred4 <- read.csv("../../data/chapter2/FRED/subsets/continuous_raw.csv")
fred4 <- fred4[, c("binominal", "F00679", "F00727", "F00709")]
colnames(fred4)[1] = "species" # this is a requirement for the phylopars function
stopifnot(all(fred4$species %in% tree$tip.label))

fred4[, 2:4] <- fred4[, 2:4] |> log() |> apply(FUN = scale, MARGIN = 2, center = TRUE, scale = TRUE) # log transform and standardize the trait data

head(fred4) # this is also a log transformed and scaled dataset!!!!
# Out:
#   species        F00679      F00727     F00709
# 1 Larix_gmelinii -0.86964523  0.3800732 0.51080990
# 2 Larix_gmelinii -0.30989917  0.1548774 0.22220517
# 3 Larix_gmelinii  0.23874590 -0.4930916 0.63144285
# 4 Larix_gmelinii  1.28396192 -1.1952738 0.42043082
# 5 Larix_gmelinii -0.95393439  0.4492205 0.63144258
# 6 Larix_gmelinii -0.06701916  0.1904641 0.02954094

# %%
# https://github.com/ericgoolsby/Rphylopars/wiki/Example-4:-Alternative-Evolutionary-Models
# if you run into errors with mvOU models - set usezscores to FALSE as explained in this thread https://github.com/ericgoolsby/Rphylopars/issues/54

# %%
# Rphylopars automatically detects multiple within-species observations and estimates within-species covariance with pheno_correlated set to TRUE
# the two fits below account for within species correlations

# with a diagonal alhpa - only phylogenetic correlation between species is accounted for, evolution of traits are treated independently (no cross trait correlations)
mvOU_diagonal <- Rphylopars::phylopars(trait_data = fred4, tree = tree, phylo_correlated = TRUE, pheno_correlated = TRUE, model = "mvOU", full_alpha = FALSE, usezscores = FALSE)

# with a full alpha matrix - phylogenetic correlation between species and correlated evolution between traits are accounted for
mvOU_full <- Rphylopars::phylopars(trait_data = fred4, tree = tree, phylo_correlated = TRUE, pheno_correlated = TRUE, model = "mvOU", full_alpha = TRUE, usezscores = FALSE)

# %%
# read https://support.minitab.com/en-us/minitab/help-and-how-to/statistical-modeling/anova/supporting-topics/anova-statistics/what-is-the-variance-covariance-matrix/
# to understand variance-covariance matrices
# see https://en.wikipedia.org/wiki/Covariance for covariance
# see https://stats.stackexchange.com/questions/17050/explanation-for-r-squared-as-ratio-of-covariances-and-variances for the relationship between correlation (R2) and covariance
# https://github.com/ericgoolsby/Rphylopars/issues/49

# %%
# from https://github.com/ericgoolsby/Rphylopars/wiki/Example-4:-Alternative-Evolutionary-Models
# The phylogenetic trait variance-covariance is the Σ matrix of the OU process, and the stationary covariance is that same matrix divided by 2*alpha.

# %%
mvOU_full
# Out:
# Phylogenetic trait variance-covariance
#             F00679      F00727      F00709
# F00679  0.03094493 -0.01826736 -0.01227627
# F00727 -0.01826736  0.02300304 -0.01129689
# F00709 -0.01227627 -0.01129689  0.03693923
#
# Phenotypic trait variance-covariance
#             F00679     F00727      F00709
# F00679  0.48128397 -0.3229709  0.01183338
# F00727 -0.32297093  0.4266235 -0.19573197
# F00709  0.01183338 -0.1957320  0.35233416
#
# % variance explained by phylogeny
#   F00679   F00727   F00709
# 51.87160 57.33765 64.76658
# mvOU alpha =
#              F00679       F00727       F00709
# F00679  0.017966975  0.001136202 -0.006836677
# F00727  0.001136202  0.014354971 -0.002530329
# F00709 -0.006836677 -0.002530329  0.026740089
#
#
# Stationary covariance =
#             F00679     F00727      F00709
# F00679  0.87695525 -0.6932728 -0.07371013
# F00727 -0.69327279  0.8033726 -0.29910170
# F00709 -0.07371013 -0.2991017  0.64356026

# %%
mvOU_diagonal
# Out:
# Phylogenetic trait variance-covariance
#              F00679      F00727       F00709
# F00679  0.032469655 -0.02322968 -0.005756741
# F00727 -0.023229683  0.02651896 -0.010789750
# F00709 -0.005756741 -0.01078975  0.028340213
#
# Phenotypic trait variance-covariance
#              F00679     F00727       F00709
# F00679  0.480277687 -0.3206001  0.009557131
# F00727 -0.320600093  0.4246606 -0.195714693
# F00709  0.009557131 -0.1957147  0.354929505
#
# % variance explained by phylogeny
#   F00679   F00727   F00709
# 51.97223 57.53394 64.50705
# mvOU alpha =
#            F00679    F00727     F00709
# F00679 0.01919707 0.0000000 0.00000000
# F00727 0.00000000 0.0179221 0.00000000
# F00709 0.00000000 0.0000000 0.01976518
#
#
# Stationary covariance =
#            F00679     F00727     F00709
# F00679  0.8456930 -0.6258137 -0.1477517
# F00727 -0.6258137  0.7398399 -0.2862968
# F00709 -0.1477517 -0.2862968  0.7169226

# %%
summary(mvOU_diagonal)
# Out:
# mvOU alpha =
#            F00679    F00727     F00709
# F00679 0.01919707 0.0000000 0.00000000
# F00727 0.00000000 0.0179221 0.00000000
# F00709 0.00000000 0.0000000 0.01976518
#        phylogenetic mean phylogenetic sd phenotypic sd
# F00679 -0.2503918        0.1802          0.6930
# F00727  0.2670933        0.1628          0.6517
# F00709 -0.1133140        0.1683          0.5958
#        % variance explained by phylogeny
# F00679 51.97
# F00727 57.53
# F00709 64.51

# %%
summary(mvOU_full)
# Out:
# mvOU alpha =
#              F00679       F00727       F00709
# F00679  0.017966975  0.001136202 -0.006836677
# F00727  0.001136202  0.014354971 -0.002530329
# F00709 -0.006836677 -0.002530329  0.026740089
#        phylogenetic mean phylogenetic sd phenotypic sd
# F00679 -0.29819824       0.1759          0.6937
# F00727  0.24459623       0.1517          0.6532
# F00709 -0.01758767       0.1922          0.5936
#        % variance explained by phylogeny
# F00679 51.87
# F00727 57.34
# F00709 64.77

# %%
stats::AIC(mvOU_diagonal)
# Out:
# [1] 27556.68

# %%
stats::AIC(mvOU_full) # full alpha matrix has a lower AIC than the diagonal one - there's evidence to correlation between traits!!!
# Out:
# [1] 27541.39

# %%
stats::AIC(mvOU_diagonal) - stats::AIC(mvOU_full)
# Out:
# [1] 15.28992

# %%
# now onto models that don't account for within species correlations (pheno_correlated=FALSE)

mvOU_diagonal_nsp <- Rphylopars::phylopars(trait_data = fred4, tree = tree, phylo_correlated = TRUE, pheno_correlated = FALSE, model = "mvOU", full_alpha = FALSE, usezscores = FALSE)
mvOU_full_nsp <- Rphylopars::phylopars(trait_data = fred4, tree = tree, phylo_correlated = TRUE, pheno_correlated = FALSE, model = "mvOU", full_alpha = TRUE, usezscores = FALSE)

# %%
summary(mvOU_diagonal_nsp)
# Out:
# mvOU alpha =
#            F00679     F00727     F00709
# F00679 0.03088403 0.00000000 0.00000000
# F00727 0.00000000 0.02656244 0.00000000
# F00709 0.00000000 0.00000000 0.02457418
#        phylogenetic mean phylogenetic sd phenotypic sd
# F00679 -0.33608615       0.2381          0.6670
# F00727  0.31370652       0.2198          0.6185
# F00709 -0.07354631       0.1880          0.5856
#        % variance explained by phylogeny
# F00679 55.51
# F00727 61.75
# F00709 65.71

# %%
summary(mvOU_full_nsp)
# Out:
# mvOU alpha =
#          F00679   F00727   F00709
# F00679 3.388095 3.889273 2.414048
# F00727 3.889273 4.517015 2.790547
# F00709 2.414048 2.790547 1.766468
#        phylogenetic mean phylogenetic sd phenotypic sd
# F00679 -0.30450758       0.1257          0.6690
# F00727  0.28629208       0.2927          0.6192
# F00709 -0.02332462       0.2352          0.5844
#        % variance explained by phylogeny
# F00679 55.25
# F00727 61.66
# F00709 65.85

# %%
stats::AIC(mvOU_diagonal_nsp) # diagonal is better than full in this case
# Out:
# [1] 33833.58

# %%
stats::AIC(mvOU_full_nsp)
# Out:
# [1] 33843.66

# %%
# since the AICs of models that did not account for within species correlation is way higher than the ones that did, there's evidence for within species correlation!!!

# %%
# OU model with same rates for all traits - these are not multivariate models (technically??)
# for the OU model, this is like a multivariate OU where the alpha matrix is diagonal and with identical values across the diagonal.

OU_model_base <- Rphylopars::phylopars(trait_data = fred4, tree = tree, phylo_correlated = TRUE, pheno_correlated = TRUE, model = "OU")

# %%
summary(OU_model_base)
# Out:
# OU alpha = 0.01889005
#        phylogenetic mean phylogenetic sd phenotypic sd
# F00679 -0.2486226        0.9214          0.6931
# F00727  0.2711781        0.8550          0.6512
# F00709 -0.1265029        0.8545          0.5960
#        % variance explained by phylogeny
# F00679 51.97
# F00727 57.60
# F00709 64.48

# %%
stats::AIC(OU_model_base) # AIC higher than our multivariate models
# Out:
# [1] 27555.23

# %%
# also try lambda models 

# univariate lambda models - traits are correlated & within species correlations accounted for
lambda_phycorr <- Rphylopars::phylopars(trait_data = fred4, tree = tree, phylo_correlated = TRUE, pheno_correlated = TRUE, model = "lambda", usezscores = FALSE)
# univariate lambda models - traits are independent & within species correlations accounted for
lambda_phynocorr <- Rphylopars::phylopars(trait_data = fred4, tree = tree, phylo_correlated = FALSE, pheno_correlated = TRUE, model = "lambda", usezscores = FALSE)
# univariate lambda models - traits are correlated & within species correlations not accounted for
lambda_phenonocorr <- Rphylopars::phylopars(trait_data = fred4, tree = tree, phylo_correlated = TRUE, pheno_correlated = FALSE, model = "lambda", usezscores = FALSE)
# no correlations whatsoever
lambda_nocorr <- Rphylopars::phylopars(trait_data = fred4, tree = tree, phylo_correlated = FALSE, pheno_correlated = FALSE, model = "lambda", usezscores = FALSE)

# %%
stats::AIC(lambda_phycorr) # the lowest AIC - cross trait correlations and within species correlations accounted for
# Out:
# [1] 27486.16

# %%
stats::AIC(lambda_phynocorr)
# Out:
# [1] 28969.26

# %%
stats::AIC(lambda_phenonocorr)
# Out:
# [1] 33651.05

# %%
stats::AIC(lambda_nocorr)
# Out:
# [1] 35225.19

# %%
35225.185440387 - 27486.1628646043
# Out:
# [1] 7739.023

# %%
lambda_phycorr
# Out:
# Phylogenetic trait variance-covariance
#               F00679       F00727        F00709
# F00679  0.0063379075 -0.004725059 -0.0008425563
# F00727 -0.0047250589  0.005910638 -0.0027578717
# F00709 -0.0008425563 -0.002757872  0.0059100039
#
# Phenotypic trait variance-covariance
#             F00679     F00727      F00709
# F00679  0.47428995 -0.3167326  0.01236117
# F00727 -0.31673258  0.4187477 -0.19249842
# F00709  0.01236117 -0.1924984  0.34808464
#
# % variance explained by phylogeny
#   F00679   F00727   F00709
# 52.57101 58.12523 65.19154
# lambda = 0.922766

# %%
lambda_phenonocorr
# Out:
# Phylogenetic trait variance-covariance
#               F00679       F00727        F00709
# F00679  6.320169e-03 -0.005428885 -1.820934e-05
# F00727 -5.428885e-03  0.006743752 -3.306008e-03
# F00709 -1.820934e-05 -0.003306008  5.404907e-03
#
# Phenotypic trait variance-covariance
#           F00679    F00727    F00709
# F00679 0.4403889 0.0000000 0.0000000
# F00727 0.0000000 0.3766257 0.0000000
# F00709 0.0000000 0.0000000 0.3354559
#
# % variance explained by phylogeny
#   F00679   F00727   F00709
# 55.96111 62.33743 66.45441
# lambda = 0.8901362

# %%
lambda_phynocorr
# Out:
# Phylogenetic trait variance-covariance
#             F00679      F00727      F00709
# F00679 0.003941414 0.000000000 0.000000000
# F00727 0.000000000 0.002898819 0.000000000
# F00709 0.000000000 0.000000000 0.006272385
#
# Phenotypic trait variance-covariance
#             F00679     F00727      F00709
# F00679  0.55502603 -0.3906294  0.02726824
# F00727 -0.39062942  0.4970106 -0.22454357
# F00709  0.02726824 -0.2245436  0.37749788
#
# % variance explained by phylogeny
#   F00679   F00727   F00709
# 44.49740 50.29894 62.25021
# lambda = 0.9764592

# %%
lambda_nocorr
# Out:
# Phylogenetic trait variance-covariance
#             F00679      F00727      F00709
# F00679 0.005980588 0.000000000 0.000000000
# F00727 0.000000000 0.005694842 0.000000000
# F00709 0.000000000 0.000000000 0.005683208
#
# Phenotypic trait variance-covariance
#           F00679    F00727    F00709
# F00679 0.4758905 0.0000000 0.0000000
# F00727 0.0000000 0.4183631 0.0000000
# F00709 0.0000000 0.0000000 0.3477872
#
# % variance explained by phylogeny
#   F00679   F00727   F00709
# 52.41095 58.16369 65.22128
# lambda = 0.9159096

# %% [markdown]
# ## ___Phylogenetic ANOVA___
# ----------------------

# %%
# https://eeob-macroevolution.github.io/Practicals/MultivariatePCMs/MultivariatePCM_Tutorial.html
# http://www.phytools.org/static.help/phylANOVA.html

# %%
fred4_raw <- read.csv("../../data/chapter2/FRED/subsets/continuous_raw.csv")
# log transform and standardize the traits
fred4_raw[, 5:7] <- fred4_raw[, 5:7] |> log() |> scale()

head(fred4_raw)
# Out:
#   binominal      F01286 F01287   F01289   F00679      F00727     F00709
# 1 Larix_gmelinii Larix  gmelinii Pinaceae -0.86964523  0.3800732 0.51080990
# 2 Larix_gmelinii Larix  gmelinii Pinaceae -0.30989917  0.1548774 0.22220517
# 3 Larix_gmelinii Larix  gmelinii Pinaceae  0.23874590 -0.4930916 0.63144285
# 4 Larix_gmelinii Larix  gmelinii Pinaceae  1.28396192 -1.1952738 0.42043082
# 5 Larix_gmelinii Larix  gmelinii Pinaceae -0.95393439  0.4492205 0.63144258
# 6 Larix_gmelinii Larix  gmelinii Pinaceae -0.06701916  0.1904641 0.02954094

# %%
varcov <- ape::vcv.phylo(tree)

# %%
RRPP::rrpp.data.frame(Y = fred4_raw[, c("F00679", "F00727", "F00709")], taxa = fred4_raw$binominal, Cov = varcov) # won't allow multiple measurements for species????
# Out:
# Error in RRPP::rrpp.data.frame(Y = fred4_raw[, c("F00679", "F00727", "F00709")], : Inputs have different numbers of observations
# Traceback:
#
# 1. stop("Inputs have different numbers of observations")
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "Inputs have different numbers of observations", base::quote(RRPP::rrpp.data.frame(Y = fred4_raw[,
#  .     c("F00679", "F00727", "F00709")], taxa = fred4_raw$binominal,
#  .     Cov = varcov)))

# %%
head(varcov)
# Out:
#                         Ratibida_pinnata Heliopsis_helianthoides Liatris_aspera
# Ratibida_pinnata        400.7877         362.4934                362.4934
# Heliopsis_helianthoides 362.4934         400.7877                362.4934
# Liatris_aspera          362.4934         362.4934                400.7877
# Arnica_sororia          362.4934         362.4934                390.5848
# Arnica_fulgens          362.4934         362.4934                390.5848
# Hymenoxys_richardsonii  362.4934         362.4934                388.3693
#                         Arnica_sororia Arnica_fulgens Hymenoxys_richardsonii
# Ratibida_pinnata        362.4934       362.4934       362.4934
# Heliopsis_helianthoides 362.4934       362.4934       362.4934
# Liatris_aspera          390.5848       390.5848       388.3693
# Arnica_sororia          400.7877       399.1072       388.3693
# Arnica_fulgens          399.1072       400.7877       388.3693
# Hymenoxys_richardsonii  388.3693       388.3693       400.7877
#                         Helianthus_agrestis Helianthus_grosseserratus
# Ratibida_pinnata        362.4934            362.4934
# Heliopsis_helianthoides 362.4934            362.4934
# Liatris_aspera          383.0923            383.0923
# Arnica_sororia          383.0923            383.0923
# Arnica_fulgens          383.0923            383.0923
# Hymenoxys_richardsonii  383.0923            383.0923
#                         Helianthus_giganteus Helianthus_maximiliani ⋯
# Ratibida_pinnata        362.4934             362.4934               ⋯
# Heliopsis_helianthoides 362.4934             362.4934               ⋯
# Liatris_aspera          383.0923             383.0923               ⋯
# Arnica_sororia          383.0923             383.0923               ⋯
# Arnica_fulgens          383.0923             383.0923               ⋯
# Hymenoxys_richardsonii  383.0923             383.0923               ⋯
#                         Sphaeropteris_medullaris Dicksonia_squarrosa
# Ratibida_pinnata        10.08512                 10.08512
# Heliopsis_helianthoides 10.08512                 10.08512
# Liatris_aspera          10.08512                 10.08512
# Arnica_sororia          10.08512                 10.08512
# Arnica_fulgens          10.08512                 10.08512
# Hymenoxys_richardsonii  10.08512                 10.08512
#                         Cibotium_barometz Sticherus_cunninghamii
# Ratibida_pinnata        10.08512          10.08512
# Heliopsis_helianthoides 10.08512          10.08512
# Liatris_aspera          10.08512          10.08512
# Arnica_sororia          10.08512          10.08512
# Arnica_fulgens          10.08512          10.08512
# Hymenoxys_richardsonii  10.08512          10.08512
#                         Dicranopteris_pedata Dicranopteris_linearis
# Ratibida_pinnata        10.08512             10.08512
# Heliopsis_helianthoides 10.08512             10.08512
# Liatris_aspera          10.08512             10.08512
# Arnica_sororia          10.08512             10.08512
# Arnica_fulgens          10.08512             10.08512
# Hymenoxys_richardsonii  10.08512             10.08512
#                         Osmunda_japonica Equisetum_hyemale Equisetum_pratense
# Ratibida_pinnata        10.08512         10.08512          10.08512
# Heliopsis_helianthoides 10.08512         10.08512          10.08512
# Liatris_aspera          10.08512         10.08512          10.08512
# Arnica_sororia          10.08512         10.08512          10.08512
# Arnica_fulgens          10.08512         10.08512          10.08512
# Hymenoxys_richardsonii  10.08512         10.08512          10.08512
#                         Lycopodium_volubile
# Ratibida_pinnata        0
# Heliopsis_helianthoides 0
# Liatris_aspera          0
# Arnica_sororia          0
# Arnica_fulgens          0
# Hymenoxys_richardsonii  0

# %%
expanded_varcov <- varcov[fred4_raw$binominal, fred4_raw$binominal]
expanded_varcov
# Out:
#                        Larix_gmelinii Larix_gmelinii Larix_gmelinii
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# ⋮                      ⋮              ⋮              ⋮
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
#                        Larix_gmelinii Larix_gmelinii Larix_gmelinii
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# ⋮                      ⋮              ⋮              ⋮
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
#                        Larix_gmelinii Larix_gmelinii Larix_gmelinii
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Larix_gmelinii         400.78767      400.78767      400.78767
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# Fraxinus_mandshurica    75.73763       75.73763       75.73763
# ⋮                      ⋮              ⋮              ⋮
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
# Handroanthus_ochraceus 75.73763       75.73763       75.73763
#                        Larix_gmelinii ⋯ Handroanthus_ochraceus
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Larix_gmelinii         400.78767      ⋯  75.73763
# Fraxinus_mandshurica    75.73763      ⋯ 329.76705
# Fraxinus_mandshurica    75.73763      ⋯ 329.76705
# Fraxinus_mandshurica    75.73763      ⋯ 329.76705
# Fraxinus_mandshurica    75.73763      ⋯ 329.76705
# Fraxinus_mandshurica    75.73763      ⋯ 329.76705
# Fraxinus_mandshurica    75.73763      ⋯ 329.76705
# Fraxinus_mandshurica    75.73763      ⋯ 329.76705
# ⋮                      ⋮              ⋱ ⋮
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
# Handroanthus_ochraceus 75.73763       ⋯ 400.7877
#                        Handroanthus_ochraceus Handroanthus_ochraceus
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# ⋮                      ⋮                      ⋮
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
#                        Handroanthus_ochraceus Handroanthus_ochraceus
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# ⋮                      ⋮                      ⋮
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
#                        Handroanthus_ochraceus Handroanthus_ochraceus
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# ⋮                      ⋮                      ⋮
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
#                        Handroanthus_ochraceus Handroanthus_ochraceus
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Larix_gmelinii          75.73763               75.73763
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# Fraxinus_mandshurica   329.76705              329.76705
# ⋮                      ⋮                      ⋮
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
# Handroanthus_ochraceus 400.7877               400.7877
#                        Handroanthus_ochraceus
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Larix_gmelinii          75.73763
# Fraxinus_mandshurica   329.76705
# Fraxinus_mandshurica   329.76705
# Fraxinus_mandshurica   329.76705
# Fraxinus_mandshurica   329.76705
# Fraxinus_mandshurica   329.76705
# Fraxinus_mandshurica   329.76705
# Fraxinus_mandshurica   329.76705
# ⋮                      ⋮
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877
# Handroanthus_ochraceus 400.7877

# %%
# try again with values in the variance-covariance matrix replicated to match the trait data
# https://eeob-macroevolution.github.io/Practicals/MultivariatePCMs/MultivariatePCM_Tutorial.html

rrpp_df <- RRPP::rrpp.data.frame(Y = fred4_raw[, c("F00679", "F00727", "F00709")], taxa = fred4_raw$binominal, Cov = expanded_varcov) # works :)

# %%
dimnames(rrpp_df$Y)[[3]]
# Out:
# Error in dimnames(rrpp_df$Y)[[3]]: subscript out of bounds
# Traceback:

# %%
# this doesn't work!!!
tm <- Sys.time()
lmod_aov <- RRPP::lm.rrpp(Y ~ taxa, Cov = expanded_varcov, data = rrpp_df, iter = 1000, print.progress = FALSE, parallel = 4) # the parallel argument ain't helping :(
tm <- Sys.time() - tm

# %%
# try phytools::phylANOVA()

load("../../data/chapter2/rdata/hie-general/ANOVA.RData") # contains RD, SRL and RTD

# %%
summary(RD) # garbage :(
# Out:
#         Length  Class  Mode
# F             1 -none- numeric
# Pf            1 -none- numeric
# T       1692601 -none- numeric
# method        1 -none- character
# Pt      1692601 -none- numeric
# Sum Sq        2 -none- numeric
# Mean Sq       2 -none- numeric

# %%
# two preconditions for one-way ANOVA are
# - normality of the distribution - use Shapiro-Wilk normality test on the residuals or raw values - if using raw values group wise processing is required
# - homegeneity of variance i.e. that all the groups share a common variance - use Levene test on the raw data

# %%
car::leveneTest(F00679~binominal, data = fred4_raw)
# Out:
# Warning message in leveneTest.default(y = y, group = group, ...):
# "group coerced to factor."
#       Df   F value  Pr(>F)
# group 1300 1.382423 1.014167e-13
#       3917       NA           NA

# %%
car::leveneTest(F00727~binominal, data = fred4_raw)
# Out:
# Warning message in leveneTest.default(y = y, group = group, ...):
# "group coerced to factor."
#       Df   F value  Pr(>F)
# group 1300 1.863513 2.181077e-47
#       3917       NA           NA

# %%
car::leveneTest(F00709~binominal, data = fred4_raw)
# Out:
# Warning message in leveneTest.default(y = y, group = group, ...):
# "group coerced to factor."
#       Df   F value  Pr(>F)
# group 1300 1.755621 7.863855e-39
#       3917       NA           NA

# %%
# consitently low p values - Levene's test is significant for all the traits
# hence the equal variance F is invalid - cannot use plain ANOVA - opt for Welch's ANOVA

# %%
oneway.test(F00679 ~ binominal, data = fred4_raw, var.equal = FALSE) # Welch ANOVA
# Out:
# Error in oneway.test(F00679 ~ binominal, data = fred4_raw, var.equal = FALSE): not enough observations
# Traceback:
#
# 1. stop("not enough observations")
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "not enough observations", base::quote(oneway.test(F00679 ~
#  .     binominal, data = fred4_raw, var.equal = FALSE)))

# %%
rd <- fred4_raw$F00679
taxa <- fred4_raw$binominal

oneway.test(rd~taxa, var.equal = FALSE)
# Out:
# Error in oneway.test(rd ~ taxa, var.equal = FALSE): not enough observations
# Traceback:
#
# 1. stop("not enough observations")
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "not enough observations", base::quote(oneway.test(rd ~ taxa,
#  .     var.equal = FALSE)))

# %%
# plain ANOVA - https://mgimond.github.io/Stats-in-R/ANOVA.html

# %%
# reporting ANOVA results based on the APA format - https://stats.stackexchange.com/questions/511332/how-to-report-the-results-of-an-anova-model-comparison
# https://www.youtube.com/watch?v=Br3xSTHuUdo
summary(rd_aov)
# Out:
#               Df Sum Sq Mean Sq F value Pr(>F)
# binominal   1300   3335  2.5653   5.339 <2e-16 ***
# Residuals   3917   1882  0.4805
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
all(tree$tip.label %in% unique(fred4_raw$binominal))
# Out:
# [1] TRUE

# %%
# https://github.com/mwpennell/geiger-v2/blob/master/R/traits.R#L1013

dat <- setNames(fred4_raw$F00679, nm = fred4_raw$binominal)
group <- setNames(fred4_raw$binominal, nm = fred4_raw$binominal) |> as.factor()

geiger::aov.phylo(dat~group, phy = tree) # won't work with duplicated records :/

# %%
# let's use plain ANOVA

# %%
aovRD <- aov(F00679 ~ binominal, data = fred4_raw)
aovSRL <- aov(F00727 ~ binominal, data = fred4_raw)
aovRTD <- aov(F00709 ~ binominal, data = fred4_raw)

# %%
# let's check if the ANOVA preconditions are met

par(mfrow = c(3, 2))
options(repr.plot.width = 12, repr.plot.height = 20)

hist(aovRD$residuals)
qqnorm(aovRD$residuals)

hist(aovSRL$residuals)
qqnorm(aovSRL$residuals)

hist(aovRTD$residuals)
qqnorm(aovRTD$residuals)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
shapiro.test(aovRD$residuals)
# Out:
# Error in shapiro.test(aovRD$residuals): sample size must be between 3 and 5000
# Traceback:
#
# 1. stop("sample size must be between 3 and 5000")
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "sample size must be between 3 and 5000", base::quote(shapiro.test(aovRD$residuals)))

# %%
# Anderson-Darling normality test - an alternative to Shapiro-Wilk test which fails to handle more than 5000 observations

nortest::ad.test(aovRD$residuals)
# Out:
# 	Anderson-Darling normality test
#
# data:  aovRD$residuals
# A = 154.7, p-value < 2.2e-16

# %%
nortest::ad.test(aovSRL$residuals)
# Out:
# 	Anderson-Darling normality test
#
# data:  aovSRL$residuals
# A = 90.935, p-value < 2.2e-16

# %%
nortest::ad.test(aovRTD$residuals)
# Out:
# 	Anderson-Darling normality test
#
# data:  aovRTD$residuals
# A = 147.66, p-value < 2.2e-16

# %%
# Remember that the null and alternative hypothesis of these tests are:
# H0: data come from a normal distribution
# H1: data do not come from a normal distribution

# since all Ps are < 0.05; we reject the null hypotheses - the data does not come from a normal dist :/
# since the normality precondition is violated - we cannot use Welch's test either

# %%
# second precondition of ANOVA is homogeneity of variances
# we can use Levene's test to confirm this

# %%
car::leveneTest(F00679~as.factor(binominal), data = fred4_raw)
# Out:
#       Df   F value  Pr(>F)
# group 1300 1.382423 1.014167e-13
#       3917       NA           NA

# %%
car::leveneTest(F00727~as.factor(binominal), data = fred4_raw)
# Out:
#       Df   F value  Pr(>F)
# group 1300 1.863513 2.181077e-47
#       3917       NA           NA

# %%
car::leveneTest(F00709~as.factor(binominal), data = fred4_raw)
# Out:
#       Df   F value  Pr(>F)
# group 1300 1.755621 7.863855e-39
#       3917       NA           NA

# %%
# https://statsandr.com/blog/anova-in-r/
# The null and alternative hypothesis for Levene's test are:
# H0: variances are equal
# H1: at least one variance is different

# since the P values are < 0.05 for all traits - we reject the null hypotheses
# the homogeneity of variance assumption does not hold here

# %%
# https://statsandr.com/blog/kruskal-wallis-test-nonparametric-version-anova/

# Kruskal-Wallis is non-parametric 
# it does not have the normality precondition

# The null and alternative hypotheses of the Kruskal-Wallis test are:
# H0: The 3 species are equal in terms of flipper length
# H1: At least one species is different from the other 2 species in terms of flipper length

# Be careful that, as for the ANOVA, the alternative hypothesis is not that all species are different in terms of flipper length. 
# The opposite of all species being equal (H0) is that at least one species is different from the others (H1).

# Second, remember that the Kruskal-Wallis test is a nonparametric test, so the normality assumption is not required. However, the independence assumption still holds.
# This means that the data, collected from a representative and randomly selected portion of the total population, should be independent between groups and within each group
# Regarding the homoscedasticity (i.e., equality of the variances): As long as you use the Kruskal-Wallis test to, in fine, compare groups, homoscedasticity is not required. 
# If you wish to compare medians, the Kruskal-Wallis test requires homoscedasticity.

# %%
kruskal.test(F00679~binominal, data = fred4_raw)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  F00679 by binominal
# Kruskal-Wallis chi-squared = 3290, df = 1300, p-value < 2.2e-16

# %%
kruskal.test(F00727~binominal, data = fred4_raw)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  F00727 by binominal
# Kruskal-Wallis chi-squared = 3359.1, df = 1300, p-value < 2.2e-16

# %%
kruskal.test(F00709~binominal, data = fred4_raw)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  F00709 by binominal
# Kruskal-Wallis chi-squared = 3789.5, df = 1300, p-value < 2.2e-16

# %%
# since the p values are < 0.05 for all the traits - we reject the H0
# however Kruskall-Wallis do not tell us which groups significantly differ from one another - just that there's at least one group that deviates from the whole

# %%
# to see which actually do - we can use Dunn's test

# %%
# dunnTest spits out a lot of stuff - maxxes out the memory
# the outputs of FSA::dunnTest are actually wrnings - not simple print messages

suppressWarnings({
    dunnRD <- FSA::dunnTest(F00679~as.factor(binominal), data = fred4_raw, method = "holm");
    dunnSRL <- FSA::dunnTest(F00727~as.factor(binominal), data = fred4_raw, method = "holm");
    dunnRTD <- FSA::dunnTest(F00709~as.factor(binominal), data = fred4_raw, method = "holm");
})
# Out:
#   Kruskal-Wallis rank sum test
#
# data: x and g
# Kruskal-Wallis chi-squared = 3289.982, df = 1300, p-value = 0

# %% [markdown]
# ## ___`ape::vcv.phylo(corr = ?)`___
# -----------------

# %%
# compare the correlation matrix with the variance-covariance matrix

# %%
tree <- ape::read.tree("../../data/chapter2/uphylomaker/FRED4_1301.tre")

# %%
par(mfrow = c(1, 2))
options(repr.plot.width = 20, repr.plot.height = 10)
image(ape::vcv.phylo(tree, corr = FALSE), axes = FALSE) # correlation matrix
image(ape::vcv.phylo(tree, corr = TRUE), axes = FALSE) # covariance matrix
# Out:
# plot without title

# %%
# plots look identical
(ape::vcv.phylo(tree, corr = FALSE) == ape::vcv.phylo(tree, corr = FALSE)) |> mean()
# Out:
# [1] 1

# %%
# both matrices are in-fact identical - so doesn't matter which matrix we used in brms :)
